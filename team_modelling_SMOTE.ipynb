# %% [markdown]
# # ***Team Modelling with SMOTE***

# %%
# Import modules

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import precision_score, recall_score, roc_auc_score, roc_curve, confusion_matrix, make_scorer, matthews_corrcoef, f1_score, classification_report, fbeta_score
from sklearn.model_selection import train_test_split, RandomizedSearchCV, GridSearchCV
from sklearn.preprocessing import StandardScaler, MinMaxScaler
import Error_analysis
from imblearn.over_sampling import SMOTE

RSEED= 42

# %%
def combine_dfs(X_test_unscaled, y_test, y_pred):
    test_comb = X_test_unscaled.copy()
    test_comb["y_true"] = y_test
    test_comb["y_pred"] = y_pred
    return test_comb

def get_classification_dfs(X_test_unscaled, y_test, y_pred):
    '''Combines the dataframes and returns all TN, FP, FN and TP'''
    test_comb = combine_dfs(X_test_unscaled, y_test, y_pred)
    false_positive = test_comb[test_comb.y_true < test_comb.y_pred]
    false_negative = test_comb[test_comb.y_true > test_comb.y_pred]
    correct = test_comb[test_comb.y_true == test_comb.y_pred]
    true_positive = correct[correct.y_pred == 1]
    true_negative = correct[correct.y_pred == 0]
    return true_negative, false_positive, false_negative, true_positive

def calculate_cost(X_test_unscaled, y_test, y_pred):
    '''Calculates the money saved by the model'''
    true_negative, false_positive, false_negative, true_positive = get_classification_dfs(X_test_unscaled, y_test, y_pred)
    reimbursements = false_negative[false_negative.SignAmount == 1].ModAmount.sum()
    avoided_reimbursements = true_positive[true_positive.SignAmount == 1].ModAmount.sum()
    print(f"You detected {true_positive.shape[0]} fraudulent transactions")
    print(f"You saved the company {round((avoided_reimbursements)/1e6, 2)} Million UGX")
    print(f"You missed {false_negative.shape[0]} fraudulent transactions")
    print(f"The company now has to reimburse frauds with a total of {round((reimbursements)/1e6, 2)} Million UGX")
    print(f"Total money saved is {round((avoided_reimbursements - reimbursements)/1e6, 2)} Million UGX")
    print(f"You incorrectly flagged {false_positive.shape[0]} legit transactions as fraudulent")

# %%
# Import Dataset

df= pd.read_csv('data/training_preprocessed.csv')

# %%
y= df.FraudResult
df.drop("FraudResult", axis=1, inplace=True)
X= df
X.drop(["TransactionId"], axis=1, inplace=True)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, random_state=RSEED)
X_test_unscaled = X_test.copy()

# %% [markdown]
# ## SMOTE-ing

# %%
smotifier = SMOTE(sampling_strategy= 0.1, random_state=RSEED, )

# %%
X_smote, y_smote = smotifier.fit_resample(X_train, y_train)
X_smote = pd.DataFrame(data= X_smote, columns=X_train.columns)
y_smote = pd.Series(data= y_smote, name="FraudResult")
smote_df_combined = X_smote.copy()
smote_df_combined["FraudResult"] = y_smote

# %%
smote_df_combined.groupby("FraudResult").count()
# Out:
#               Year  Month   Week    Day  is_workday  is_worktime  SignAmount  \
# FraudResult
# 0            71601  71601  71601  71601       71601        71601       71601
# 1             7160   7160   7160   7160        7160         7160        7160
#
#              ModAmount  ProviderId_1  ProviderId_2  ...  PricingStrategy_2  \
# FraudResult                                         ...
# 0                71601         71601         71601  ...              71601
# 1                 7160          7160          7160  ...               7160
#
#              PricingStrategy_4  batch_size  total_transactions_by_customer  \
# FraudResult
# 0                        71601       71601                           71601
# 1                         7160        7160                            7160
#
#              transactions_by_customer_this_month  \
# FraudResult
# 0                                          71601
# 1                                           7160
#
#              transactions_by_customer_this_week  \
# FraudResult
# 0                                         71601
# 1                                          7160
#
#              transactions_by_customer_this_day  day_vs_week  day_vs_month  \
# FraudResult
# 0                                        71601        71601         71601
# 1                                         7160         7160          7160
#
#              week_vs_month
# FraudResult
# 0                    71601
# 1                     7160
#
# [2 rows x 62 columns]

# %% [markdown]
# Simple forest, no scaling

# %%
rf = RandomForestClassifier(random_state=RSEED)
rf.fit(X_smote, y_smote)
y_pred = rf.predict(X_test)

# %%
print(confusion_matrix(y_test, y_pred))
print("----" * 10)
print(f"Recall is:{round(recall_score(y_test, y_pred),3)}")
print(f"F1 is:{round(f1_score(y_test, y_pred),3)}")
print(f"F2 is: {round(fbeta_score(y_test, y_pred, beta=2),3)}")
print("----" * 10)
calculate_cost(X_test_unscaled, y_test, y_pred)
# Out:
# [[23858    10]
#  [   15    33]]
# ----------------------------------------
# Recall is:0.688
# F1 is:0.725
# F2 is: 0.702
# ----------------------------------------
# You detected 33 fraudulent transactions
# You saved the company 86.82 Million UGX
# You missed 15 fraudulent transactions
# The company now has to reimburse frauds with a total of 11.0 Million UGX
# Total money saved is 75.82 Million UGX
# You incorrectly flagged 10 legit transactions as fraudulent

# %% [markdown]
# Scaling

# %%
minmax = MinMaxScaler()
stdsc = StandardScaler()
X_smote['ModAmount'] = stdsc.fit_transform(pd.DataFrame(X_smote['ModAmount']))
X_smote['ModAmount'] = stdsc.transform(pd.DataFrame(X_smote['ModAmount']));

# %%
rf = RandomForestClassifier(random_state=RSEED)
rf.fit(X_smote, y_smote)
y_pred = rf.predict(X_test)

# %%
print(confusion_matrix(y_test, y_pred))
print("----" * 10)
print(f"Recall is:{round(recall_score(y_test, y_pred),3)}")
print(f"F1 is:{round(f1_score(y_test, y_pred),3)}")
print(f"F2 is: {round(fbeta_score(y_test, y_pred, beta=2),3)}")
print("----" * 10)
calculate_cost(X_test_unscaled, y_test, y_pred)
# Out:
# [[19144  4724]
#  [    8    40]]
# ----------------------------------------
# Recall is:0.833
# F1 is:0.017
# F2 is: 0.04
# ----------------------------------------
# You detected 40 fraudulent transactions
# You saved the company 90.56 Million UGX
# You missed 8 fraudulent transactions
# The company now has to reimburse frauds with a total of 7.26 Million UGX
# Total money saved is 83.3 Million UGX
# You incorrectly flagged 4724 legit transactions as fraudulent

# %%
rf = RandomForestClassifier(random_state=RSEED, max_depth = None, max_features ='sqrt', max_leaf_nodes= None, min_samples_split= 5, n_estimators= 100)
rf.fit(X_smote, y_smote)
y_pred = rf.predict(X_test)
print(confusion_matrix(y_test, y_pred))
print("----" * 10)
print(f"Recall is:{round(recall_score(y_test, y_pred),3)}")
print(f"F1 is:{round(f1_score(y_test, y_pred),3)}")
print(f"F2 is: {round(fbeta_score(y_test, y_pred, beta=2),3)}")
print("----" * 10)
calculate_cost(X_test_unscaled, y_test, y_pred)
# Out:
# [[19226  4642]
#  [    6    42]]
# ----------------------------------------
# Recall is:0.875
# F1 is:0.018
# F2 is: 0.043
# ----------------------------------------
# You detected 42 fraudulent transactions
# You saved the company 92.0 Million UGX
# You missed 6 fraudulent transactions
# The company now has to reimburse frauds with a total of 5.82 Million UGX
# Total money saved is 86.18 Million UGX
# You incorrectly flagged 4642 legit transactions as fraudulent

# %% [markdown]
# rf = RandomForestClassifier(random_state=RSEED, max_depth = None, max_features ='sqrt', max_leaf_nodes= None, min_samples_split= 5, n_estimators= 100)
# SMOTE strategy 1 => Recall is:0.625, F1 is:0.106

# %%
param_grid = {'n_estimators': np.linspace(50, 150, 3).astype(int),
                'max_depth': [None] + list(np.linspace(3, 100, 3).astype(int)),
                'max_features': ['sqrt'] + list(np.arange(0.5, 1, 0.25)),
                'max_leaf_nodes': list(np.linspace(20, 100, 3).astype(int)) + [None],
                'min_samples_split':[2,5,10]
                }

scorer = make_scorer(matthews_corrcoef)
rand_grid = GridSearchCV(rf, param_grid=param_grid, n_jobs=-1, scoring=scorer, verbose=5)

# %%
rand_grid.fit(X_smote, y_smote)
# Out:
# Fitting 5 folds for each of 432 candidates, totalling 2160 fits
# [CV 1/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=20, min_samples_split=2, n_estimators=50;, score=0.956 total time=   1.4s
# [CV 2/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=20, min_samples_split=2, n_estimators=50;, score=0.960 total time=   1.5s
# [CV 3/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=20, min_samples_split=2, n_estimators=50;, score=0.953 total time=   1.5s
# [CV 5/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=20, min_samples_split=2, n_estimators=50;, score=0.958 total time=   1.6s
# [CV 4/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=20, min_samples_split=2, n_estimators=50;, score=0.959 total time=   1.6s
# [CV 1/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=20, min_samples_split=2, n_estimators=100;, score=0.954 total time=   2.9s
# [CV 2/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=20, min_samples_split=2, n_estimators=100;, score=0.959 total time=   3.1s
# [CV 3/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=20, min_samples_split=2, n_estimators=100;, score=0.961 total time=   2.9s
# [CV 5/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=20, min_samples_split=2, n_estimators=100;, score=0.958 total time=   3.3s
# [CV 4/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=20, min_samples_split=2, n_estimators=100;, score=0.961 total time=   3.6s
# [CV 1/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=20, min_samples_split=5, n_estimators=50;, score=0.956 total time=   2.0s
# [CV 1/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=20, min_samples_split=2, n_estimators=150;, score=0.960 total time=   4.7s
# [CV 3/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=20, min_samples_split=2, n_estimators=150;, score=0.959 total time=   4.7s
# [CV 2/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=20, min_samples_split=5, n_estimators=50;, score=0.960 total time=   1.8s
# [CV 3/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=20, min_samples_split=5, n_estimators=50;, score=0.953 total time=   1.7s
# [CV 2/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=20, min_samples_split=2, n_estimators=150;, score=0.960 total time=   5.1s
# [CV 4/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=20, min_samples_split=5, n_estimators=50;, score=0.959 total time=   2.0s
# [CV 5/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=20, min_samples_split=5, n_estimators=50;, score=0.958 total time=   1.9s
# [CV 5/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=20, min_samples_split=2, n_estimators=150;, score=0.958 total time=   5.5s
# [CV 4/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=20, min_samples_split=2, n_estimators=150;, score=0.962 total time=   5.6s
# [CV 1/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=20, min_samples_split=5, n_estimators=100;, score=0.954 total time=   3.5s
# [CV 2/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=20, min_samples_split=5, n_estimators=100;, score=0.959 total time=   3.5s
# [CV 3/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=20, min_samples_split=5, n_estimators=100;, score=0.959 total time=   3.6s
# [CV 4/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=20, min_samples_split=5, n_estimators=100;, score=0.961 total time=   3.7s
# [CV 5/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=20, min_samples_split=5, n_estimators=100;, score=0.958 total time=   3.6s
# [CV 1/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=20, min_samples_split=10, n_estimators=50;, score=0.956 total time=   2.1s
# [CV 2/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=20, min_samples_split=10, n_estimators=50;, score=0.959 total time=   2.1s
# [CV 3/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=20, min_samples_split=10, n_estimators=50;, score=0.954 total time=   2.0s
# [CV 1/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=20, min_samples_split=5, n_estimators=150;, score=0.960 total time=   5.3s
# [CV 2/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=20, min_samples_split=5, n_estimators=150;, score=0.960 total time=   5.3s
# [CV 4/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=20, min_samples_split=10, n_estimators=50;, score=0.959 total time=   1.7s
# [CV 3/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=20, min_samples_split=5, n_estimators=150;, score=0.959 total time=   5.5s
# [CV 5/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=20, min_samples_split=10, n_estimators=50;, score=0.958 total time=   1.7s
# [CV 5/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=20, min_samples_split=5, n_estimators=150;, score=0.958 total time=   5.7s
# [CV 4/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=20, min_samples_split=5, n_estimators=150;, score=0.962 total time=   6.1s
# [CV 1/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=20, min_samples_split=10, n_estimators=100;, score=0.954 total time=   3.4s
# [CV 2/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=20, min_samples_split=10, n_estimators=100;, score=0.959 total time=   3.7s
# [CV 3/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=20, min_samples_split=10, n_estimators=100;, score=0.962 total time=   3.6s
# [CV 4/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=20, min_samples_split=10, n_estimators=100;, score=0.960 total time=   3.7s
# [CV 5/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=20, min_samples_split=10, n_estimators=100;, score=0.958 total time=   3.7s
# [CV 1/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=60, min_samples_split=2, n_estimators=50;, score=0.988 total time=   2.0s
# [CV 1/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=20, min_samples_split=10, n_estimators=150;, score=0.960 total time=   5.2s
# [CV 3/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=60, min_samples_split=2, n_estimators=50;, score=0.994 total time=   2.0s
# [CV 2/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=60, min_samples_split=2, n_estimators=50;, score=0.994 total time=   2.0s
# [CV 2/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=20, min_samples_split=10, n_estimators=150;, score=0.960 total time=   5.1s
# [CV 3/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=20, min_samples_split=10, n_estimators=150;, score=0.959 total time=   5.0s
# [CV 4/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=20, min_samples_split=10, n_estimators=150;, score=0.962 total time=   5.1s
# [CV 4/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=60, min_samples_split=2, n_estimators=50;, score=0.994 total time=   1.9s
# [CV 5/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=60, min_samples_split=2, n_estimators=50;, score=0.996 total time=   2.0s
# [CV 5/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=20, min_samples_split=10, n_estimators=150;, score=0.958 total time=   5.3s
# [CV 1/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=60, min_samples_split=2, n_estimators=100;, score=0.993 total time=   4.4s
# [CV 2/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=60, min_samples_split=2, n_estimators=100;, score=0.995 total time=   4.4s
# [CV 3/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=60, min_samples_split=2, n_estimators=100;, score=0.994 total time=   4.1s
# [CV 4/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=60, min_samples_split=2, n_estimators=100;, score=0.993 total time=   4.3s
# [CV 5/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=60, min_samples_split=2, n_estimators=100;, score=0.995 total time=   4.2s
# [CV 1/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=60, min_samples_split=5, n_estimators=50;, score=0.989 total time=   1.7s
# [CV 3/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=60, min_samples_split=5, n_estimators=50;, score=0.995 total time=   1.5s
# [CV 2/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=60, min_samples_split=5, n_estimators=50;, score=0.994 total time=   1.7s
# [CV 2/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=60, min_samples_split=2, n_estimators=150;, score=0.995 total time=   5.9s
# [CV 1/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=60, min_samples_split=2, n_estimators=150;, score=0.993 total time=   6.1s
# [CV 3/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=60, min_samples_split=2, n_estimators=150;, score=0.994 total time=   5.6s
# [CV 4/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=60, min_samples_split=5, n_estimators=50;, score=0.994 total time=   1.8s
# [CV 5/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=60, min_samples_split=5, n_estimators=50;, score=0.996 total time=   1.7s
# [CV 5/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=60, min_samples_split=2, n_estimators=150;, score=0.995 total time=   4.8s
# [CV 4/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=60, min_samples_split=2, n_estimators=150;, score=0.995 total time=   5.2s
# [CV 1/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=60, min_samples_split=5, n_estimators=100;, score=0.992 total time=   3.4s
# [CV 2/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=60, min_samples_split=5, n_estimators=100;, score=0.995 total time=   3.2s
# [CV 3/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=60, min_samples_split=5, n_estimators=100;, score=0.994 total time=   3.2s
# [CV 4/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=60, min_samples_split=5, n_estimators=100;, score=0.994 total time=   3.2s
# [CV 5/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=60, min_samples_split=5, n_estimators=100;, score=0.995 total time=   3.2s
# [CV 1/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=60, min_samples_split=10, n_estimators=50;, score=0.988 total time=   1.8s
# [CV 2/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=60, min_samples_split=10, n_estimators=50;, score=0.993 total time=   1.8s
# [CV 3/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=60, min_samples_split=10, n_estimators=50;, score=0.994 total time=   1.6s
# [CV 1/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=60, min_samples_split=5, n_estimators=150;, score=0.993 total time=   4.9s
# [CV 2/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=60, min_samples_split=5, n_estimators=150;, score=0.996 total time=   5.0s
# [CV 4/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=60, min_samples_split=10, n_estimators=50;, score=0.994 total time=   1.7s
# [CV 3/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=60, min_samples_split=5, n_estimators=150;, score=0.994 total time=   5.0s
# [CV 5/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=60, min_samples_split=10, n_estimators=50;, score=0.994 total time=   1.6s
# [CV 4/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=60, min_samples_split=5, n_estimators=150;, score=0.995 total time=   4.8s
# [CV 5/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=60, min_samples_split=5, n_estimators=150;, score=0.995 total time=   5.0s
# [CV 1/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=60, min_samples_split=10, n_estimators=100;, score=0.989 total time=   3.2s
# [CV 2/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=60, min_samples_split=10, n_estimators=100;, score=0.995 total time=   3.4s
# [CV 3/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=60, min_samples_split=10, n_estimators=100;, score=0.994 total time=   3.3s
# [CV 4/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=60, min_samples_split=10, n_estimators=100;, score=0.994 total time=   3.4s
# [CV 5/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=60, min_samples_split=10, n_estimators=100;, score=0.994 total time=   3.2s
# [CV 1/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=100, min_samples_split=2, n_estimators=50;, score=0.993 total time=   1.8s
# [CV 1/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=60, min_samples_split=10, n_estimators=150;, score=0.993 total time=   4.7s
# [CV 2/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=100, min_samples_split=2, n_estimators=50;, score=0.997 total time=   1.9s
# [CV 3/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=100, min_samples_split=2, n_estimators=50;, score=0.997 total time=   1.7s
# [CV 2/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=60, min_samples_split=10, n_estimators=150;, score=0.995 total time=   4.8s
# [CV 3/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=60, min_samples_split=10, n_estimators=150;, score=0.994 total time=   4.7s
# [CV 4/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=100, min_samples_split=2, n_estimators=50;, score=0.995 total time=   2.0s
# [CV 5/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=100, min_samples_split=2, n_estimators=50;, score=0.999 total time=   1.9s
# [CV 4/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=60, min_samples_split=10, n_estimators=150;, score=0.995 total time=   5.3s
# [CV 5/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=60, min_samples_split=10, n_estimators=150;, score=0.994 total time=   5.4s
# [CV 1/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=100, min_samples_split=2, n_estimators=100;, score=0.992 total time=   3.6s
# [CV 2/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=100, min_samples_split=2, n_estimators=100;, score=0.997 total time=   3.8s
# [CV 3/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=100, min_samples_split=2, n_estimators=100;, score=0.997 total time=   3.8s
# [CV 4/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=100, min_samples_split=2, n_estimators=100;, score=0.995 total time=   3.8s
# [CV 5/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=100, min_samples_split=2, n_estimators=100;, score=0.998 total time=   3.6s
# [CV 1/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=100, min_samples_split=5, n_estimators=50;, score=0.993 total time=   1.7s
# [CV 2/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=100, min_samples_split=5, n_estimators=50;, score=0.996 total time=   2.0s
# [CV 1/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=100, min_samples_split=2, n_estimators=150;, score=0.992 total time=   5.2s
# [CV 3/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=100, min_samples_split=5, n_estimators=50;, score=0.997 total time=   1.7s
# [CV 2/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=100, min_samples_split=2, n_estimators=150;, score=0.997 total time=   5.1s
# [CV 4/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=100, min_samples_split=5, n_estimators=50;, score=0.995 total time=   1.6s
# [CV 3/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=100, min_samples_split=2, n_estimators=150;, score=0.997 total time=   5.0s
# [CV 5/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=100, min_samples_split=5, n_estimators=50;, score=0.999 total time=   2.0s
# [CV 4/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=100, min_samples_split=2, n_estimators=150;, score=0.995 total time=   5.4s
# [CV 5/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=100, min_samples_split=2, n_estimators=150;, score=0.999 total time=   5.4s
# [CV 1/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=100, min_samples_split=5, n_estimators=100;, score=0.992 total time=   3.6s
# [CV 2/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=100, min_samples_split=5, n_estimators=100;, score=0.997 total time=   3.5s
# [CV 3/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=100, min_samples_split=5, n_estimators=100;, score=0.996 total time=   3.7s
# [CV 4/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=100, min_samples_split=5, n_estimators=100;, score=0.995 total time=   3.7s
# [CV 5/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=100, min_samples_split=5, n_estimators=100;, score=0.997 total time=   3.6s
# [CV 1/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=100, min_samples_split=10, n_estimators=50;, score=0.994 total time=   1.8s
# [CV 2/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=100, min_samples_split=10, n_estimators=50;, score=0.997 total time=   1.7s
# [CV 3/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=100, min_samples_split=10, n_estimators=50;, score=0.996 total time=   1.9s
# [CV 1/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=100, min_samples_split=5, n_estimators=150;, score=0.992 total time=   5.2s
# [CV 3/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=100, min_samples_split=5, n_estimators=150;, score=0.996 total time=   5.1s
# [CV 2/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=100, min_samples_split=5, n_estimators=150;, score=0.996 total time=   5.6s
# [CV 4/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=100, min_samples_split=10, n_estimators=50;, score=0.995 total time=   1.9s
# [CV 5/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=100, min_samples_split=10, n_estimators=50;, score=0.999 total time=   1.9s
# [CV 4/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=100, min_samples_split=5, n_estimators=150;, score=0.995 total time=   5.5s
# [CV 5/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=100, min_samples_split=5, n_estimators=150;, score=0.998 total time=   5.6s
# [CV 1/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=100, min_samples_split=10, n_estimators=100;, score=0.993 total time=   3.7s
# [CV 2/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=100, min_samples_split=10, n_estimators=100;, score=0.997 total time=   3.6s
# [CV 3/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=100, min_samples_split=10, n_estimators=100;, score=0.996 total time=   3.6s
# [CV 4/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=100, min_samples_split=10, n_estimators=100;, score=0.995 total time=   3.8s
# [CV 5/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=100, min_samples_split=10, n_estimators=100;, score=0.998 total time=   4.1s
# [CV 1/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=None, min_samples_split=2, n_estimators=50;, score=0.992 total time=   2.1s
# [CV 2/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=None, min_samples_split=2, n_estimators=50;, score=0.998 total time=   2.1s
# [CV 1/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=100, min_samples_split=10, n_estimators=150;, score=0.993 total time=   5.6s
# [CV 3/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=None, min_samples_split=2, n_estimators=50;, score=0.998 total time=   2.1s
# [CV 2/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=100, min_samples_split=10, n_estimators=150;, score=0.996 total time=   5.5s
# [CV 3/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=100, min_samples_split=10, n_estimators=150;, score=0.996 total time=   5.3s
# [CV 4/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=None, min_samples_split=2, n_estimators=50;, score=0.995 total time=   2.1s
# [CV 5/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=None, min_samples_split=2, n_estimators=50;, score=1.000 total time=   1.9s
# [CV 4/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=100, min_samples_split=10, n_estimators=150;, score=0.995 total time=   5.9s
# [CV 5/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=100, min_samples_split=10, n_estimators=150;, score=0.999 total time=   5.7s
# [CV 1/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=None, min_samples_split=2, n_estimators=100;, score=0.990 total time=   3.7s
# [CV 2/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=None, min_samples_split=2, n_estimators=100;, score=0.997 total time=   3.9s
# [CV 3/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=None, min_samples_split=2, n_estimators=100;, score=0.998 total time=   4.0s
# [CV 4/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=None, min_samples_split=2, n_estimators=100;, score=0.997 total time=   4.1s
# [CV 5/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=None, min_samples_split=2, n_estimators=100;, score=1.000 total time=   3.9s
# [CV 1/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=None, min_samples_split=5, n_estimators=50;, score=0.991 total time=   1.9s
# [CV 1/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=None, min_samples_split=2, n_estimators=150;, score=0.990 total time=   5.3s
# [CV 2/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=None, min_samples_split=5, n_estimators=50;, score=0.997 total time=   1.9s
# [CV 3/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=None, min_samples_split=5, n_estimators=50;, score=0.998 total time=   1.9s
# [CV 2/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=None, min_samples_split=2, n_estimators=150;, score=0.998 total time=   5.7s
# [CV 3/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=None, min_samples_split=2, n_estimators=150;, score=0.998 total time=   5.8s
# [CV 4/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=None, min_samples_split=5, n_estimators=50;, score=0.997 total time=   2.1s
# [CV 5/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=None, min_samples_split=5, n_estimators=50;, score=1.000 total time=   2.0s
# [CV 4/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=None, min_samples_split=2, n_estimators=150;, score=0.997 total time=   5.9s
# [CV 5/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=None, min_samples_split=2, n_estimators=150;, score=1.000 total time=   5.8s
# [CV 1/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=None, min_samples_split=5, n_estimators=100;, score=0.990 total time=   3.8s
# [CV 2/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=None, min_samples_split=5, n_estimators=100;, score=0.997 total time=   4.0s
# [CV 3/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=None, min_samples_split=5, n_estimators=100;, score=0.998 total time=   3.9s
# [CV 4/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=None, min_samples_split=5, n_estimators=100;, score=0.996 total time=   4.3s
# [CV 5/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=None, min_samples_split=5, n_estimators=100;, score=1.000 total time=   3.9s
# [CV 1/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=None, min_samples_split=10, n_estimators=50;, score=0.993 total time=   1.8s
# [CV 2/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=None, min_samples_split=10, n_estimators=50;, score=0.997 total time=   1.9s
# [CV 1/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=None, min_samples_split=5, n_estimators=150;, score=0.990 total time=   5.6s
# [CV 3/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=None, min_samples_split=10, n_estimators=50;, score=0.998 total time=   2.0s
# [CV 2/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=None, min_samples_split=5, n_estimators=150;, score=0.997 total time=   5.7s
# [CV 4/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=None, min_samples_split=10, n_estimators=50;, score=0.996 total time=   2.1s
# [CV 3/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=None, min_samples_split=5, n_estimators=150;, score=0.998 total time=   6.0s
# [CV 5/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=None, min_samples_split=10, n_estimators=50;, score=1.000 total time=   2.1s
# [CV 4/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=None, min_samples_split=5, n_estimators=150;, score=0.996 total time=   6.0s
# [CV 5/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=None, min_samples_split=5, n_estimators=150;, score=1.000 total time=   6.0s
# [CV 1/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=None, min_samples_split=10, n_estimators=100;, score=0.993 total time=   3.9s
# [CV 2/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=None, min_samples_split=10, n_estimators=100;, score=0.997 total time=   4.0s
# [CV 3/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=None, min_samples_split=10, n_estimators=100;, score=0.998 total time=   4.0s
# [CV 4/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=None, min_samples_split=10, n_estimators=100;, score=0.996 total time=   4.0s
# [CV 5/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=None, min_samples_split=10, n_estimators=100;, score=1.000 total time=   3.9s
# [CV 1/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=None, min_samples_split=10, n_estimators=150;, score=0.994 total time=   5.6s
# [CV 2/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=None, min_samples_split=10, n_estimators=150;, score=0.997 total time=   5.7s
# [CV 3/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=None, min_samples_split=10, n_estimators=150;, score=0.997 total time=   5.7s
# [CV 1/5] END max_depth=None, max_features=0.5, max_leaf_nodes=20, min_samples_split=2, n_estimators=50;, score=0.987 total time=   4.2s
# [CV 2/5] END max_depth=None, max_features=0.5, max_leaf_nodes=20, min_samples_split=2, n_estimators=50;, score=0.995 total time=   4.0s
# [CV 3/5] END max_depth=None, max_features=0.5, max_leaf_nodes=20, min_samples_split=2, n_estimators=50;, score=0.993 total time=   3.9s
# [CV 4/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=None, min_samples_split=10, n_estimators=150;, score=0.996 total time=   5.9s
# [CV 5/5] END max_depth=None, max_features=sqrt, max_leaf_nodes=None, min_samples_split=10, n_estimators=150;, score=1.000 total time=   6.0s
# [CV 4/5] END max_depth=None, max_features=0.5, max_leaf_nodes=20, min_samples_split=2, n_estimators=50;, score=0.992 total time=   4.4s
# [CV 5/5] END max_depth=None, max_features=0.5, max_leaf_nodes=20, min_samples_split=2, n_estimators=50;, score=0.991 total time=   4.1s
# [CV 2/5] END max_depth=None, max_features=0.5, max_leaf_nodes=20, min_samples_split=2, n_estimators=100;, score=0.995 total time=   7.5s
# [CV 1/5] END max_depth=None, max_features=0.5, max_leaf_nodes=20, min_samples_split=2, n_estimators=100;, score=0.992 total time=   8.2s
# [CV 3/5] END max_depth=None, max_features=0.5, max_leaf_nodes=20, min_samples_split=2, n_estimators=100;, score=0.995 total time=   7.9s
# [CV 5/5] END max_depth=None, max_features=0.5, max_leaf_nodes=20, min_samples_split=2, n_estimators=100;, score=0.986 total time=   7.9s
# [CV 4/5] END max_depth=None, max_features=0.5, max_leaf_nodes=20, min_samples_split=2, n_estimators=100;, score=0.985 total time=   8.6s
# [CV 2/5] END max_depth=None, max_features=0.5, max_leaf_nodes=20, min_samples_split=5, n_estimators=50;, score=0.995 total time=   3.5s
# [CV 1/5] END max_depth=None, max_features=0.5, max_leaf_nodes=20, min_samples_split=5, n_estimators=50;, score=0.987 total time=   4.3s
# [CV 3/5] END max_depth=None, max_features=0.5, max_leaf_nodes=20, min_samples_split=5, n_estimators=50;, score=0.996 total time=   3.9s
# [CV 1/5] END max_depth=None, max_features=0.5, max_leaf_nodes=20, min_samples_split=2, n_estimators=150;, score=0.994 total time=  12.1s
# [CV 2/5] END max_depth=None, max_features=0.5, max_leaf_nodes=20, min_samples_split=2, n_estimators=150;, score=0.996 total time=  11.2s
# [CV 3/5] END max_depth=None, max_features=0.5, max_leaf_nodes=20, min_samples_split=2, n_estimators=150;, score=0.995 total time=  11.9s
# [CV 5/5] END max_depth=None, max_features=0.5, max_leaf_nodes=20, min_samples_split=5, n_estimators=50;, score=0.992 total time=   4.0s
# [CV 4/5] END max_depth=None, max_features=0.5, max_leaf_nodes=20, min_samples_split=5, n_estimators=50;, score=0.990 total time=   4.4s
# [CV 5/5] END max_depth=None, max_features=0.5, max_leaf_nodes=20, min_samples_split=2, n_estimators=150;, score=0.991 total time=  12.1s
# [CV 4/5] END max_depth=None, max_features=0.5, max_leaf_nodes=20, min_samples_split=2, n_estimators=150;, score=0.985 total time=  12.9s
# [CV 2/5] END max_depth=None, max_features=0.5, max_leaf_nodes=20, min_samples_split=5, n_estimators=100;, score=0.995 total time=   7.4s
# [CV 1/5] END max_depth=None, max_features=0.5, max_leaf_nodes=20, min_samples_split=5, n_estimators=100;, score=0.992 total time=   8.4s
# [CV 3/5] END max_depth=None, max_features=0.5, max_leaf_nodes=20, min_samples_split=5, n_estimators=100;, score=0.995 total time=   7.7s
# [CV 4/5] END max_depth=None, max_features=0.5, max_leaf_nodes=20, min_samples_split=5, n_estimators=100;, score=0.985 total time=   8.5s
# [CV 5/5] END max_depth=None, max_features=0.5, max_leaf_nodes=20, min_samples_split=5, n_estimators=100;, score=0.991 total time=   7.9s
# [CV 1/5] END max_depth=None, max_features=0.5, max_leaf_nodes=20, min_samples_split=10, n_estimators=50;, score=0.987 total time=   4.2s
# [CV 2/5] END max_depth=None, max_features=0.5, max_leaf_nodes=20, min_samples_split=10, n_estimators=50;, score=0.995 total time=   4.0s
# [CV 3/5] END max_depth=None, max_features=0.5, max_leaf_nodes=20, min_samples_split=10, n_estimators=50;, score=0.995 total time=   3.8s
# [CV 1/5] END max_depth=None, max_features=0.5, max_leaf_nodes=20, min_samples_split=5, n_estimators=150;, score=0.994 total time=  12.2s
# [CV 4/5] END max_depth=None, max_features=0.5, max_leaf_nodes=20, min_samples_split=10, n_estimators=50;, score=0.990 total time=   4.3s
# [CV 2/5] END max_depth=None, max_features=0.5, max_leaf_nodes=20, min_samples_split=5, n_estimators=150;, score=0.996 total time=  11.4s
# [CV 5/5] END max_depth=None, max_features=0.5, max_leaf_nodes=20, min_samples_split=10, n_estimators=50;, score=0.994 total time=   4.3s
# [CV 3/5] END max_depth=None, max_features=0.5, max_leaf_nodes=20, min_samples_split=5, n_estimators=150;, score=0.995 total time=  11.9s
# [CV 5/5] END max_depth=None, max_features=0.5, max_leaf_nodes=20, min_samples_split=5, n_estimators=150;, score=0.993 total time=  12.1s
# [CV 4/5] END max_depth=None, max_features=0.5, max_leaf_nodes=20, min_samples_split=5, n_estimators=150;, score=0.985 total time=  13.0s
# [CV 1/5] END max_depth=None, max_features=0.5, max_leaf_nodes=20, min_samples_split=10, n_estimators=100;, score=0.993 total time=   8.1s
# [CV 2/5] END max_depth=None, max_features=0.5, max_leaf_nodes=20, min_samples_split=10, n_estimators=100;, score=0.995 total time=   7.9s
# [CV 3/5] END max_depth=None, max_features=0.5, max_leaf_nodes=20, min_samples_split=10, n_estimators=100;, score=0.995 total time=   7.9s
# [CV 5/5] END max_depth=None, max_features=0.5, max_leaf_nodes=20, min_samples_split=10, n_estimators=100;, score=0.992 total time=   7.9s
# [CV 4/5] END max_depth=None, max_features=0.5, max_leaf_nodes=20, min_samples_split=10, n_estimators=100;, score=0.985 total time=   8.6s
# [CV 1/5] END max_depth=None, max_features=0.5, max_leaf_nodes=60, min_samples_split=2, n_estimators=50;, score=0.994 total time=   4.4s
# [CV 2/5] END max_depth=None, max_features=0.5, max_leaf_nodes=60, min_samples_split=2, n_estimators=50;, score=0.998 total time=   4.4s
# [CV 3/5] END max_depth=None, max_features=0.5, max_leaf_nodes=60, min_samples_split=2, n_estimators=50;, score=0.998 total time=   4.4s
# [CV 1/5] END max_depth=None, max_features=0.5, max_leaf_nodes=20, min_samples_split=10, n_estimators=150;, score=0.994 total time=  12.2s
# [CV 2/5] END max_depth=None, max_features=0.5, max_leaf_nodes=20, min_samples_split=10, n_estimators=150;, score=0.996 total time=  11.7s
# [CV 3/5] END max_depth=None, max_features=0.5, max_leaf_nodes=20, min_samples_split=10, n_estimators=150;, score=0.995 total time=  11.5s
# [CV 4/5] END max_depth=None, max_features=0.5, max_leaf_nodes=60, min_samples_split=2, n_estimators=50;, score=0.995 total time=   5.0s
# [CV 5/5] END max_depth=None, max_features=0.5, max_leaf_nodes=60, min_samples_split=2, n_estimators=50;, score=0.999 total time=   4.5s
# [CV 5/5] END max_depth=None, max_features=0.5, max_leaf_nodes=20, min_samples_split=10, n_estimators=150;, score=0.994 total time=  12.6s
# [CV 4/5] END max_depth=None, max_features=0.5, max_leaf_nodes=20, min_samples_split=10, n_estimators=150;, score=0.985 total time=  13.0s
# [CV 2/5] END max_depth=None, max_features=0.5, max_leaf_nodes=60, min_samples_split=2, n_estimators=100;, score=0.998 total time=   8.8s
# [CV 1/5] END max_depth=None, max_features=0.5, max_leaf_nodes=60, min_samples_split=2, n_estimators=100;, score=0.994 total time=   9.3s
# [CV 3/5] END max_depth=None, max_features=0.5, max_leaf_nodes=60, min_samples_split=2, n_estimators=100;, score=0.998 total time=   9.3s
# [CV 4/5] END max_depth=None, max_features=0.5, max_leaf_nodes=60, min_samples_split=2, n_estimators=100;, score=0.995 total time=  10.2s
# [CV 5/5] END max_depth=None, max_features=0.5, max_leaf_nodes=60, min_samples_split=2, n_estimators=100;, score=1.000 total time=   9.4s
# [CV 1/5] END max_depth=None, max_features=0.5, max_leaf_nodes=60, min_samples_split=5, n_estimators=50;, score=0.995 total time=   4.6s
# [CV 2/5] END max_depth=None, max_features=0.5, max_leaf_nodes=60, min_samples_split=5, n_estimators=50;, score=0.998 total time=   4.1s
# [CV 3/5] END max_depth=None, max_features=0.5, max_leaf_nodes=60, min_samples_split=5, n_estimators=50;, score=0.998 total time=   4.5s
# [CV 1/5] END max_depth=None, max_features=0.5, max_leaf_nodes=60, min_samples_split=2, n_estimators=150;, score=0.995 total time=  13.9s
# [CV 2/5] END max_depth=None, max_features=0.5, max_leaf_nodes=60, min_samples_split=2, n_estimators=150;, score=0.998 total time=  13.5s
# [CV 3/5] END max_depth=None, max_features=0.5, max_leaf_nodes=60, min_samples_split=2, n_estimators=150;, score=0.998 total time=  13.8s
# [CV 4/5] END max_depth=None, max_features=0.5, max_leaf_nodes=60, min_samples_split=5, n_estimators=50;, score=0.996 total time=   4.8s
# [CV 5/5] END max_depth=None, max_features=0.5, max_leaf_nodes=60, min_samples_split=5, n_estimators=50;, score=0.999 total time=   4.6s
# [CV 5/5] END max_depth=None, max_features=0.5, max_leaf_nodes=60, min_samples_split=2, n_estimators=150;, score=1.000 total time=  13.3s
# [CV 4/5] END max_depth=None, max_features=0.5, max_leaf_nodes=60, min_samples_split=2, n_estimators=150;, score=0.995 total time=  14.5s
# [CV 1/5] END max_depth=None, max_features=0.5, max_leaf_nodes=60, min_samples_split=5, n_estimators=100;, score=0.995 total time=   9.4s
# [CV 2/5] END max_depth=None, max_features=0.5, max_leaf_nodes=60, min_samples_split=5, n_estimators=100;, score=0.998 total time=   8.7s
# [CV 3/5] END max_depth=None, max_features=0.5, max_leaf_nodes=60, min_samples_split=5, n_estimators=100;, score=0.998 total time=   9.0s
# [CV 5/5] END max_depth=None, max_features=0.5, max_leaf_nodes=60, min_samples_split=5, n_estimators=100;, score=0.999 total time=   8.8s
# [CV 4/5] END max_depth=None, max_features=0.5, max_leaf_nodes=60, min_samples_split=5, n_estimators=100;, score=0.996 total time=   9.7s
# [CV 1/5] END max_depth=None, max_features=0.5, max_leaf_nodes=60, min_samples_split=10, n_estimators=50;, score=0.995 total time=   4.6s
# [CV 2/5] END max_depth=None, max_features=0.5, max_leaf_nodes=60, min_samples_split=10, n_estimators=50;, score=0.998 total time=   4.3s
# [CV 3/5] END max_depth=None, max_features=0.5, max_leaf_nodes=60, min_samples_split=10, n_estimators=50;, score=0.997 total time=   4.3s
# [CV 1/5] END max_depth=None, max_features=0.5, max_leaf_nodes=60, min_samples_split=5, n_estimators=150;, score=0.995 total time=  13.6s
# [CV 2/5] END max_depth=None, max_features=0.5, max_leaf_nodes=60, min_samples_split=5, n_estimators=150;, score=0.998 total time=  13.0s
# [CV 3/5] END max_depth=None, max_features=0.5, max_leaf_nodes=60, min_samples_split=5, n_estimators=150;, score=0.998 total time=  13.2s
# [CV 4/5] END max_depth=None, max_features=0.5, max_leaf_nodes=60, min_samples_split=10, n_estimators=50;, score=0.995 total time=   4.7s
# [CV 5/5] END max_depth=None, max_features=0.5, max_leaf_nodes=60, min_samples_split=10, n_estimators=50;, score=0.999 total time=   4.6s
# [CV 5/5] END max_depth=None, max_features=0.5, max_leaf_nodes=60, min_samples_split=5, n_estimators=150;, score=0.999 total time=  13.5s
# [CV 4/5] END max_depth=None, max_features=0.5, max_leaf_nodes=60, min_samples_split=5, n_estimators=150;, score=0.995 total time=  14.7s
# [CV 2/5] END max_depth=None, max_features=0.5, max_leaf_nodes=60, min_samples_split=10, n_estimators=100;, score=0.998 total time=   8.5s
# [CV 1/5] END max_depth=None, max_features=0.5, max_leaf_nodes=60, min_samples_split=10, n_estimators=100;, score=0.995 total time=   9.6s
# [CV 3/5] END max_depth=None, max_features=0.5, max_leaf_nodes=60, min_samples_split=10, n_estimators=100;, score=0.997 total time=   8.8s
# [CV 5/5] END max_depth=None, max_features=0.5, max_leaf_nodes=60, min_samples_split=10, n_estimators=100;, score=0.999 total time=   9.0s
# [CV 4/5] END max_depth=None, max_features=0.5, max_leaf_nodes=60, min_samples_split=10, n_estimators=100;, score=0.995 total time=   9.9s
# [CV 1/5] END max_depth=None, max_features=0.5, max_leaf_nodes=100, min_samples_split=2, n_estimators=50;, score=0.994 total time=   4.6s
# [CV 2/5] END max_depth=None, max_features=0.5, max_leaf_nodes=100, min_samples_split=2, n_estimators=50;, score=0.998 total time=   4.2s
# [CV 3/5] END max_depth=None, max_features=0.5, max_leaf_nodes=100, min_samples_split=2, n_estimators=50;, score=0.998 total time=   4.4s
# [CV 1/5] END max_depth=None, max_features=0.5, max_leaf_nodes=60, min_samples_split=10, n_estimators=150;, score=0.995 total time=  13.8s
# [CV 2/5] END max_depth=None, max_features=0.5, max_leaf_nodes=60, min_samples_split=10, n_estimators=150;, score=0.998 total time=  12.9s
# [CV 4/5] END max_depth=None, max_features=0.5, max_leaf_nodes=100, min_samples_split=2, n_estimators=50;, score=0.995 total time=   4.8s
# [CV 5/5] END max_depth=None, max_features=0.5, max_leaf_nodes=100, min_samples_split=2, n_estimators=50;, score=1.000 total time=   4.5s
# [CV 3/5] END max_depth=None, max_features=0.5, max_leaf_nodes=60, min_samples_split=10, n_estimators=150;, score=0.997 total time=  13.3s
# [CV 5/5] END max_depth=None, max_features=0.5, max_leaf_nodes=60, min_samples_split=10, n_estimators=150;, score=0.999 total time=  13.7s
# [CV 4/5] END max_depth=None, max_features=0.5, max_leaf_nodes=60, min_samples_split=10, n_estimators=150;, score=0.995 total time=  14.5s
# [CV 2/5] END max_depth=None, max_features=0.5, max_leaf_nodes=100, min_samples_split=2, n_estimators=100;, score=0.998 total time=   8.6s
# [CV 1/5] END max_depth=None, max_features=0.5, max_leaf_nodes=100, min_samples_split=2, n_estimators=100;, score=0.993 total time=   9.4s
# [CV 3/5] END max_depth=None, max_features=0.5, max_leaf_nodes=100, min_samples_split=2, n_estimators=100;, score=0.998 total time=   8.9s
# [CV 4/5] END max_depth=None, max_features=0.5, max_leaf_nodes=100, min_samples_split=2, n_estimators=100;, score=0.996 total time=   9.5s
# [CV 5/5] END max_depth=None, max_features=0.5, max_leaf_nodes=100, min_samples_split=2, n_estimators=100;, score=1.000 total time=   9.1s
# [CV 1/5] END max_depth=None, max_features=0.5, max_leaf_nodes=100, min_samples_split=5, n_estimators=50;, score=0.995 total time=   4.6s
# [CV 2/5] END max_depth=None, max_features=0.5, max_leaf_nodes=100, min_samples_split=5, n_estimators=50;, score=0.998 total time=   4.4s
# [CV 3/5] END max_depth=None, max_features=0.5, max_leaf_nodes=100, min_samples_split=5, n_estimators=50;, score=0.998 total time=   4.5s
# [CV 1/5] END max_depth=None, max_features=0.5, max_leaf_nodes=100, min_samples_split=2, n_estimators=150;, score=0.993 total time=  13.6s
# [CV 2/5] END max_depth=None, max_features=0.5, max_leaf_nodes=100, min_samples_split=2, n_estimators=150;, score=0.998 total time=  13.0s
# [CV 3/5] END max_depth=None, max_features=0.5, max_leaf_nodes=100, min_samples_split=2, n_estimators=150;, score=0.998 total time=  13.4s
# [CV 4/5] END max_depth=None, max_features=0.5, max_leaf_nodes=100, min_samples_split=5, n_estimators=50;, score=0.996 total time=   4.9s
# [CV 5/5] END max_depth=None, max_features=0.5, max_leaf_nodes=100, min_samples_split=5, n_estimators=50;, score=0.999 total time=   4.7s
# [CV 5/5] END max_depth=None, max_features=0.5, max_leaf_nodes=100, min_samples_split=2, n_estimators=150;, score=1.000 total time=  13.9s
# [CV 4/5] END max_depth=None, max_features=0.5, max_leaf_nodes=100, min_samples_split=2, n_estimators=150;, score=0.995 total time=  14.7s
# [CV 2/5] END max_depth=None, max_features=0.5, max_leaf_nodes=100, min_samples_split=5, n_estimators=100;, score=0.998 total time=   8.6s
# [CV 1/5] END max_depth=None, max_features=0.5, max_leaf_nodes=100, min_samples_split=5, n_estimators=100;, score=0.995 total time=   9.4s
# [CV 3/5] END max_depth=None, max_features=0.5, max_leaf_nodes=100, min_samples_split=5, n_estimators=100;, score=0.998 total time=   9.1s
# [CV 4/5] END max_depth=None, max_features=0.5, max_leaf_nodes=100, min_samples_split=5, n_estimators=100;, score=0.996 total time=   9.9s
# [CV 5/5] END max_depth=None, max_features=0.5, max_leaf_nodes=100, min_samples_split=5, n_estimators=100;, score=0.999 total time=   9.4s
# [CV 1/5] END max_depth=None, max_features=0.5, max_leaf_nodes=100, min_samples_split=10, n_estimators=50;, score=0.995 total time=   4.5s
# [CV 2/5] END max_depth=None, max_features=0.5, max_leaf_nodes=100, min_samples_split=10, n_estimators=50;, score=0.998 total time=   4.3s
# [CV 3/5] END max_depth=None, max_features=0.5, max_leaf_nodes=100, min_samples_split=10, n_estimators=50;, score=0.997 total time=   4.6s
# [CV 1/5] END max_depth=None, max_features=0.5, max_leaf_nodes=100, min_samples_split=5, n_estimators=150;, score=0.995 total time=  14.5s
# [CV 2/5] END max_depth=None, max_features=0.5, max_leaf_nodes=100, min_samples_split=5, n_estimators=150;, score=0.998 total time=  13.4s
# [CV 4/5] END max_depth=None, max_features=0.5, max_leaf_nodes=100, min_samples_split=10, n_estimators=50;, score=0.995 total time=   5.0s
# [CV 3/5] END max_depth=None, max_features=0.5, max_leaf_nodes=100, min_samples_split=5, n_estimators=150;, score=0.998 total time=  13.8s
# [CV 5/5] END max_depth=None, max_features=0.5, max_leaf_nodes=100, min_samples_split=10, n_estimators=50;, score=0.999 total time=   4.6s
# [CV 5/5] END max_depth=None, max_features=0.5, max_leaf_nodes=100, min_samples_split=5, n_estimators=150;, score=1.000 total time=  13.8s
# [CV 4/5] END max_depth=None, max_features=0.5, max_leaf_nodes=100, min_samples_split=5, n_estimators=150;, score=0.995 total time=  14.7s
# [CV 1/5] END max_depth=None, max_features=0.5, max_leaf_nodes=100, min_samples_split=10, n_estimators=100;, score=0.995 total time=   9.3s
# [CV 2/5] END max_depth=None, max_features=0.5, max_leaf_nodes=100, min_samples_split=10, n_estimators=100;, score=0.998 total time=   8.2s
# [CV 3/5] END max_depth=None, max_features=0.5, max_leaf_nodes=100, min_samples_split=10, n_estimators=100;, score=0.997 total time=   8.6s
# [CV 5/5] END max_depth=None, max_features=0.5, max_leaf_nodes=100, min_samples_split=10, n_estimators=100;, score=0.999 total time=   9.1s
# [CV 4/5] END max_depth=None, max_features=0.5, max_leaf_nodes=100, min_samples_split=10, n_estimators=100;, score=0.995 total time=   9.9s
# [CV 1/5] END max_depth=None, max_features=0.5, max_leaf_nodes=None, min_samples_split=2, n_estimators=50;, score=0.994 total time=   4.4s
# [CV 2/5] END max_depth=None, max_features=0.5, max_leaf_nodes=None, min_samples_split=2, n_estimators=50;, score=0.998 total time=   4.3s
# [CV 3/5] END max_depth=None, max_features=0.5, max_leaf_nodes=None, min_samples_split=2, n_estimators=50;, score=0.998 total time=   4.5s
# [CV 1/5] END max_depth=None, max_features=0.5, max_leaf_nodes=100, min_samples_split=10, n_estimators=150;, score=0.995 total time=  13.8s
# [CV 2/5] END max_depth=None, max_features=0.5, max_leaf_nodes=100, min_samples_split=10, n_estimators=150;, score=0.998 total time=  13.2s
# [CV 3/5] END max_depth=None, max_features=0.5, max_leaf_nodes=100, min_samples_split=10, n_estimators=150;, score=0.997 total time=  13.5s
# [CV 4/5] END max_depth=None, max_features=0.5, max_leaf_nodes=None, min_samples_split=2, n_estimators=50;, score=0.995 total time=   4.7s
# [CV 5/5] END max_depth=None, max_features=0.5, max_leaf_nodes=None, min_samples_split=2, n_estimators=50;, score=1.000 total time=   4.4s
# [CV 5/5] END max_depth=None, max_features=0.5, max_leaf_nodes=100, min_samples_split=10, n_estimators=150;, score=1.000 total time=  13.5s
# [CV 4/5] END max_depth=None, max_features=0.5, max_leaf_nodes=100, min_samples_split=10, n_estimators=150;, score=0.995 total time=  14.6s
# [CV 2/5] END max_depth=None, max_features=0.5, max_leaf_nodes=None, min_samples_split=2, n_estimators=100;, score=0.998 total time=   8.3s
# [CV 1/5] END max_depth=None, max_features=0.5, max_leaf_nodes=None, min_samples_split=2, n_estimators=100;, score=0.994 total time=   8.9s
# [CV 3/5] END max_depth=None, max_features=0.5, max_leaf_nodes=None, min_samples_split=2, n_estimators=100;, score=0.998 total time=   9.0s
# [CV 5/5] END max_depth=None, max_features=0.5, max_leaf_nodes=None, min_samples_split=2, n_estimators=100;, score=1.000 total time=   9.2s
# [CV 4/5] END max_depth=None, max_features=0.5, max_leaf_nodes=None, min_samples_split=2, n_estimators=100;, score=0.995 total time=   9.8s
# [CV 1/5] END max_depth=None, max_features=0.5, max_leaf_nodes=None, min_samples_split=5, n_estimators=50;, score=0.994 total time=   4.4s
# [CV 2/5] END max_depth=None, max_features=0.5, max_leaf_nodes=None, min_samples_split=5, n_estimators=50;, score=0.997 total time=   4.2s
# [CV 3/5] END max_depth=None, max_features=0.5, max_leaf_nodes=None, min_samples_split=5, n_estimators=50;, score=0.998 total time=   4.6s
# [CV 1/5] END max_depth=None, max_features=0.5, max_leaf_nodes=None, min_samples_split=2, n_estimators=150;, score=0.994 total time=  13.5s
# [CV 2/5] END max_depth=None, max_features=0.5, max_leaf_nodes=None, min_samples_split=2, n_estimators=150;, score=0.998 total time=  12.7s
# [CV 3/5] END max_depth=None, max_features=0.5, max_leaf_nodes=None, min_samples_split=2, n_estimators=150;, score=0.998 total time=  13.1s
# [CV 4/5] END max_depth=None, max_features=0.5, max_leaf_nodes=None, min_samples_split=5, n_estimators=50;, score=0.996 total time=   4.7s
# [CV 5/5] END max_depth=None, max_features=0.5, max_leaf_nodes=None, min_samples_split=5, n_estimators=50;, score=0.999 total time=   4.5s
# [CV 5/5] END max_depth=None, max_features=0.5, max_leaf_nodes=None, min_samples_split=2, n_estimators=150;, score=1.000 total time=  13.6s
# [CV 4/5] END max_depth=None, max_features=0.5, max_leaf_nodes=None, min_samples_split=2, n_estimators=150;, score=0.995 total time=  14.7s
# [CV 2/5] END max_depth=None, max_features=0.5, max_leaf_nodes=None, min_samples_split=5, n_estimators=100;, score=0.998 total time=   8.5s
# [CV 1/5] END max_depth=None, max_features=0.5, max_leaf_nodes=None, min_samples_split=5, n_estimators=100;, score=0.995 total time=   9.3s
# [CV 3/5] END max_depth=None, max_features=0.5, max_leaf_nodes=None, min_samples_split=5, n_estimators=100;, score=0.998 total time=   8.9s
# [CV 5/5] END max_depth=None, max_features=0.5, max_leaf_nodes=None, min_samples_split=5, n_estimators=100;, score=1.000 total time=   9.1s
# [CV 4/5] END max_depth=None, max_features=0.5, max_leaf_nodes=None, min_samples_split=5, n_estimators=100;, score=0.995 total time=  10.0s
# [CV 1/5] END max_depth=None, max_features=0.5, max_leaf_nodes=None, min_samples_split=10, n_estimators=50;, score=0.995 total time=   4.6s
# [CV 2/5] END max_depth=None, max_features=0.5, max_leaf_nodes=None, min_samples_split=10, n_estimators=50;, score=0.998 total time=   4.4s
# [CV 1/5] END max_depth=None, max_features=0.5, max_leaf_nodes=None, min_samples_split=5, n_estimators=150;, score=0.995 total time=  13.9s
# [CV 3/5] END max_depth=None, max_features=0.5, max_leaf_nodes=None, min_samples_split=10, n_estimators=50;, score=0.997 total time=   4.6s
# [CV 2/5] END max_depth=None, max_features=0.5, max_leaf_nodes=None, min_samples_split=5, n_estimators=150;, score=0.998 total time=  13.2s
# [CV 3/5] END max_depth=None, max_features=0.5, max_leaf_nodes=None, min_samples_split=5, n_estimators=150;, score=0.998 total time=  13.4s
# ...
# [CV 5/5] END max_depth=100, max_features=0.75, max_leaf_nodes=60, min_samples_split=5, n_estimators=100;, score=1.000 total time=  15.1s
# [CV 1/5] END max_depth=100, max_features=0.75, max_leaf_nodes=60, min_samples_split=10, n_estimators=50;, score=0.995 total time=   7.6s
# [CV 2/5] END max_depth=100, max_features=0.75, max_leaf_nodes=60, min_samples_split=10, n_estimators=50;, score=0.998 total time=   6.4s
# [CV 3/5] END max_depth=100, max_features=0.75, max_leaf_nodes=60, min_samples_split=10, n_estimators=50;, score=0.997 total time=   7.1s
# [CV 2/5] END max_depth=100, max_features=0.75, max_leaf_nodes=60, min_samples_split=5, n_estimators=150;, score=0.998 total time=  20.0s
# [CV 1/5] END max_depth=100, max_features=0.75, max_leaf_nodes=60, min_samples_split=5, n_estimators=150;, score=0.995 total time=  22.8s
# [CV 3/5] END max_depth=100, max_features=0.75, max_leaf_nodes=60, min_samples_split=5, n_estimators=150;, score=0.997 total time=  21.3s
# [CV 4/5] END max_depth=100, max_features=0.75, max_leaf_nodes=60, min_samples_split=10, n_estimators=50;, score=0.995 total time=   8.0s
# [CV 5/5] END max_depth=100, max_features=0.75, max_leaf_nodes=60, min_samples_split=10, n_estimators=50;, score=0.999 total time=   7.5s
# [CV 4/5] END max_depth=100, max_features=0.75, max_leaf_nodes=60, min_samples_split=5, n_estimators=150;, score=0.995 total time=  23.2s
# [CV 5/5] END max_depth=100, max_features=0.75, max_leaf_nodes=60, min_samples_split=5, n_estimators=150;, score=1.000 total time=  22.5s
# [CV 1/5] END max_depth=100, max_features=0.75, max_leaf_nodes=60, min_samples_split=10, n_estimators=100;, score=0.995 total time=  15.1s
# [CV 2/5] END max_depth=100, max_features=0.75, max_leaf_nodes=60, min_samples_split=10, n_estimators=100;, score=0.997 total time=  13.2s
# [CV 3/5] END max_depth=100, max_features=0.75, max_leaf_nodes=60, min_samples_split=10, n_estimators=100;, score=0.998 total time=  14.1s
# [CV 5/5] END max_depth=100, max_features=0.75, max_leaf_nodes=60, min_samples_split=10, n_estimators=100;, score=1.000 total time=  15.2s
# [CV 4/5] END max_depth=100, max_features=0.75, max_leaf_nodes=60, min_samples_split=10, n_estimators=100;, score=0.995 total time=  15.9s
# [CV 1/5] END max_depth=100, max_features=0.75, max_leaf_nodes=100, min_samples_split=2, n_estimators=50;, score=0.995 total time=   7.4s
# [CV 2/5] END max_depth=100, max_features=0.75, max_leaf_nodes=100, min_samples_split=2, n_estimators=50;, score=0.998 total time=   6.7s
# [CV 1/5] END max_depth=100, max_features=0.75, max_leaf_nodes=60, min_samples_split=10, n_estimators=150;, score=0.995 total time=  22.2s
# [CV 3/5] END max_depth=100, max_features=0.75, max_leaf_nodes=100, min_samples_split=2, n_estimators=50;, score=0.998 total time=   6.9s
# [CV 2/5] END max_depth=100, max_features=0.75, max_leaf_nodes=60, min_samples_split=10, n_estimators=150;, score=0.998 total time=  19.9s
# [CV 4/5] END max_depth=100, max_features=0.75, max_leaf_nodes=100, min_samples_split=2, n_estimators=50;, score=0.995 total time=   8.1s
# [CV 3/5] END max_depth=100, max_features=0.75, max_leaf_nodes=60, min_samples_split=10, n_estimators=150;, score=0.998 total time=  21.2s
# [CV 5/5] END max_depth=100, max_features=0.75, max_leaf_nodes=100, min_samples_split=2, n_estimators=50;, score=1.000 total time=   7.6s
# [CV 5/5] END max_depth=100, max_features=0.75, max_leaf_nodes=60, min_samples_split=10, n_estimators=150;, score=0.999 total time=  22.2s
# [CV 4/5] END max_depth=100, max_features=0.75, max_leaf_nodes=60, min_samples_split=10, n_estimators=150;, score=0.995 total time=  23.5s
# [CV 2/5] END max_depth=100, max_features=0.75, max_leaf_nodes=100, min_samples_split=2, n_estimators=100;, score=0.998 total time=  13.2s
# [CV 1/5] END max_depth=100, max_features=0.75, max_leaf_nodes=100, min_samples_split=2, n_estimators=100;, score=0.995 total time=  15.4s
# [CV 3/5] END max_depth=100, max_features=0.75, max_leaf_nodes=100, min_samples_split=2, n_estimators=100;, score=0.998 total time=  14.5s
# [CV 5/5] END max_depth=100, max_features=0.75, max_leaf_nodes=100, min_samples_split=2, n_estimators=100;, score=1.000 total time=  15.1s
# [CV 4/5] END max_depth=100, max_features=0.75, max_leaf_nodes=100, min_samples_split=2, n_estimators=100;, score=0.995 total time=  15.9s
# [CV 1/5] END max_depth=100, max_features=0.75, max_leaf_nodes=100, min_samples_split=5, n_estimators=50;, score=0.995 total time=   7.4s
# [CV 2/5] END max_depth=100, max_features=0.75, max_leaf_nodes=100, min_samples_split=5, n_estimators=50;, score=0.998 total time=   6.4s
# [CV 3/5] END max_depth=100, max_features=0.75, max_leaf_nodes=100, min_samples_split=5, n_estimators=50;, score=0.997 total time=   6.8s
# [CV 1/5] END max_depth=100, max_features=0.75, max_leaf_nodes=100, min_samples_split=2, n_estimators=150;, score=0.995 total time=  22.3s
# [CV 2/5] END max_depth=100, max_features=0.75, max_leaf_nodes=100, min_samples_split=2, n_estimators=150;, score=0.998 total time=  19.5s
# [CV 3/5] END max_depth=100, max_features=0.75, max_leaf_nodes=100, min_samples_split=2, n_estimators=150;, score=0.998 total time=  20.5s
# [CV 4/5] END max_depth=100, max_features=0.75, max_leaf_nodes=100, min_samples_split=5, n_estimators=50;, score=0.995 total time=   7.9s
# [CV 5/5] END max_depth=100, max_features=0.75, max_leaf_nodes=100, min_samples_split=5, n_estimators=50;, score=1.000 total time=   7.4s
# [CV 5/5] END max_depth=100, max_features=0.75, max_leaf_nodes=100, min_samples_split=2, n_estimators=150;, score=1.000 total time=  21.8s
# [CV 4/5] END max_depth=100, max_features=0.75, max_leaf_nodes=100, min_samples_split=2, n_estimators=150;, score=0.995 total time=  23.7s
# [CV 2/5] END max_depth=100, max_features=0.75, max_leaf_nodes=100, min_samples_split=5, n_estimators=100;, score=0.998 total time=  13.0s
# [CV 1/5] END max_depth=100, max_features=0.75, max_leaf_nodes=100, min_samples_split=5, n_estimators=100;, score=0.995 total time=  14.8s
# [CV 3/5] END max_depth=100, max_features=0.75, max_leaf_nodes=100, min_samples_split=5, n_estimators=100;, score=0.998 total time=  13.9s
# [CV 4/5] END max_depth=100, max_features=0.75, max_leaf_nodes=100, min_samples_split=5, n_estimators=100;, score=0.995 total time=  15.5s
# [CV 5/5] END max_depth=100, max_features=0.75, max_leaf_nodes=100, min_samples_split=5, n_estimators=100;, score=1.000 total time=  14.9s
# [CV 1/5] END max_depth=100, max_features=0.75, max_leaf_nodes=100, min_samples_split=10, n_estimators=50;, score=0.995 total time=   7.7s
# [CV 2/5] END max_depth=100, max_features=0.75, max_leaf_nodes=100, min_samples_split=10, n_estimators=50;, score=0.998 total time=   6.5s
# [CV 3/5] END max_depth=100, max_features=0.75, max_leaf_nodes=100, min_samples_split=10, n_estimators=50;, score=0.997 total time=   6.9s
# [CV 2/5] END max_depth=100, max_features=0.75, max_leaf_nodes=100, min_samples_split=5, n_estimators=150;, score=0.998 total time=  19.6s
# [CV 1/5] END max_depth=100, max_features=0.75, max_leaf_nodes=100, min_samples_split=5, n_estimators=150;, score=0.995 total time=  22.3s
# [CV 3/5] END max_depth=100, max_features=0.75, max_leaf_nodes=100, min_samples_split=5, n_estimators=150;, score=0.997 total time=  20.9s
# [CV 4/5] END max_depth=100, max_features=0.75, max_leaf_nodes=100, min_samples_split=10, n_estimators=50;, score=0.995 total time=   8.1s
# [CV 5/5] END max_depth=100, max_features=0.75, max_leaf_nodes=100, min_samples_split=10, n_estimators=50;, score=0.999 total time=   7.5s
# [CV 5/5] END max_depth=100, max_features=0.75, max_leaf_nodes=100, min_samples_split=5, n_estimators=150;, score=1.000 total time=  22.4s
# [CV 4/5] END max_depth=100, max_features=0.75, max_leaf_nodes=100, min_samples_split=5, n_estimators=150;, score=0.995 total time=  23.6s
# [CV 2/5] END max_depth=100, max_features=0.75, max_leaf_nodes=100, min_samples_split=10, n_estimators=100;, score=0.997 total time=  13.3s
# [CV 1/5] END max_depth=100, max_features=0.75, max_leaf_nodes=100, min_samples_split=10, n_estimators=100;, score=0.995 total time=  14.8s
# [CV 3/5] END max_depth=100, max_features=0.75, max_leaf_nodes=100, min_samples_split=10, n_estimators=100;, score=0.998 total time=  14.1s
# [CV 4/5] END max_depth=100, max_features=0.75, max_leaf_nodes=100, min_samples_split=10, n_estimators=100;, score=0.995 total time=  15.9s
# [CV 5/5] END max_depth=100, max_features=0.75, max_leaf_nodes=100, min_samples_split=10, n_estimators=100;, score=1.000 total time=  15.1s
# [CV 1/5] END max_depth=100, max_features=0.75, max_leaf_nodes=None, min_samples_split=2, n_estimators=50;, score=0.994 total time=   7.5s
# [CV 2/5] END max_depth=100, max_features=0.75, max_leaf_nodes=None, min_samples_split=2, n_estimators=50;, score=0.998 total time=   6.2s
# [CV 3/5] END max_depth=100, max_features=0.75, max_leaf_nodes=None, min_samples_split=2, n_estimators=50;, score=0.998 total time=   6.7s
# [CV 1/5] END max_depth=100, max_features=0.75, max_leaf_nodes=100, min_samples_split=10, n_estimators=150;, score=0.995 total time=  22.6s
# [CV 2/5] END max_depth=100, max_features=0.75, max_leaf_nodes=100, min_samples_split=10, n_estimators=150;, score=0.998 total time=  19.3s
# [CV 4/5] END max_depth=100, max_features=0.75, max_leaf_nodes=None, min_samples_split=2, n_estimators=50;, score=0.995 total time=   8.0s
# [CV 3/5] END max_depth=100, max_features=0.75, max_leaf_nodes=100, min_samples_split=10, n_estimators=150;, score=0.998 total time=  21.0s
# [CV 5/5] END max_depth=100, max_features=0.75, max_leaf_nodes=None, min_samples_split=2, n_estimators=50;, score=1.000 total time=   7.6s
# [CV 5/5] END max_depth=100, max_features=0.75, max_leaf_nodes=100, min_samples_split=10, n_estimators=150;, score=1.000 total time=  22.2s
# [CV 4/5] END max_depth=100, max_features=0.75, max_leaf_nodes=100, min_samples_split=10, n_estimators=150;, score=0.995 total time=  23.6s
# [CV 1/5] END max_depth=100, max_features=0.75, max_leaf_nodes=None, min_samples_split=2, n_estimators=100;, score=0.994 total time=  14.3s
# [CV 2/5] END max_depth=100, max_features=0.75, max_leaf_nodes=None, min_samples_split=2, n_estimators=100;, score=0.998 total time=  12.8s
# [CV 3/5] END max_depth=100, max_features=0.75, max_leaf_nodes=None, min_samples_split=2, n_estimators=100;, score=0.998 total time=  13.7s
# [CV 5/5] END max_depth=100, max_features=0.75, max_leaf_nodes=None, min_samples_split=2, n_estimators=100;, score=1.000 total time=  14.1s
# [CV 4/5] END max_depth=100, max_features=0.75, max_leaf_nodes=None, min_samples_split=2, n_estimators=100;, score=0.995 total time=  15.4s
# [CV 1/5] END max_depth=100, max_features=0.75, max_leaf_nodes=None, min_samples_split=5, n_estimators=50;, score=0.995 total time=   7.3s
# [CV 2/5] END max_depth=100, max_features=0.75, max_leaf_nodes=None, min_samples_split=5, n_estimators=50;, score=0.998 total time=   6.4s
# [CV 3/5] END max_depth=100, max_features=0.75, max_leaf_nodes=None, min_samples_split=5, n_estimators=50;, score=0.998 total time=   6.6s
# [CV 1/5] END max_depth=100, max_features=0.75, max_leaf_nodes=None, min_samples_split=2, n_estimators=150;, score=0.995 total time=  21.4s
# [CV 2/5] END max_depth=100, max_features=0.75, max_leaf_nodes=None, min_samples_split=2, n_estimators=150;, score=0.998 total time=  19.4s
# [CV 4/5] END max_depth=100, max_features=0.75, max_leaf_nodes=None, min_samples_split=5, n_estimators=50;, score=0.996 total time=   7.8s
# [CV 3/5] END max_depth=100, max_features=0.75, max_leaf_nodes=None, min_samples_split=2, n_estimators=150;, score=0.998 total time=  20.2s
# [CV 5/5] END max_depth=100, max_features=0.75, max_leaf_nodes=None, min_samples_split=5, n_estimators=50;, score=1.000 total time=   7.2s
# [CV 5/5] END max_depth=100, max_features=0.75, max_leaf_nodes=None, min_samples_split=2, n_estimators=150;, score=1.000 total time=  21.4s
# [CV 4/5] END max_depth=100, max_features=0.75, max_leaf_nodes=None, min_samples_split=2, n_estimators=150;, score=0.995 total time=  23.2s
# [CV 2/5] END max_depth=100, max_features=0.75, max_leaf_nodes=None, min_samples_split=5, n_estimators=100;, score=0.998 total time=  12.7s
# [CV 1/5] END max_depth=100, max_features=0.75, max_leaf_nodes=None, min_samples_split=5, n_estimators=100;, score=0.995 total time=  14.2s
# [CV 3/5] END max_depth=100, max_features=0.75, max_leaf_nodes=None, min_samples_split=5, n_estimators=100;, score=0.998 total time=  13.5s
# [CV 4/5] END max_depth=100, max_features=0.75, max_leaf_nodes=None, min_samples_split=5, n_estimators=100;, score=0.996 total time=  15.4s
# [CV 5/5] END max_depth=100, max_features=0.75, max_leaf_nodes=None, min_samples_split=5, n_estimators=100;, score=1.000 total time=  14.7s
# [CV 1/5] END max_depth=100, max_features=0.75, max_leaf_nodes=None, min_samples_split=10, n_estimators=50;, score=0.995 total time=   7.2s
# [CV 2/5] END max_depth=100, max_features=0.75, max_leaf_nodes=None, min_samples_split=10, n_estimators=50;, score=0.998 total time=   6.3s
# [CV 3/5] END max_depth=100, max_features=0.75, max_leaf_nodes=None, min_samples_split=10, n_estimators=50;, score=0.998 total time=   6.9s
# [CV 1/5] END max_depth=100, max_features=0.75, max_leaf_nodes=None, min_samples_split=5, n_estimators=150;, score=0.995 total time=  21.1s
# [CV 2/5] END max_depth=100, max_features=0.75, max_leaf_nodes=None, min_samples_split=5, n_estimators=150;, score=0.998 total time=  19.2s
# [CV 3/5] END max_depth=100, max_features=0.75, max_leaf_nodes=None, min_samples_split=5, n_estimators=150;, score=0.998 total time=  19.9s
# [CV 4/5] END max_depth=100, max_features=0.75, max_leaf_nodes=None, min_samples_split=10, n_estimators=50;, score=0.995 total time=   8.0s
# [CV 5/5] END max_depth=100, max_features=0.75, max_leaf_nodes=None, min_samples_split=10, n_estimators=50;, score=0.999 total time=   7.5s
# [CV 5/5] END max_depth=100, max_features=0.75, max_leaf_nodes=None, min_samples_split=5, n_estimators=150;, score=1.000 total time=  21.2s
# [CV 4/5] END max_depth=100, max_features=0.75, max_leaf_nodes=None, min_samples_split=5, n_estimators=150;, score=0.995 total time=  22.5s
# [CV 2/5] END max_depth=100, max_features=0.75, max_leaf_nodes=None, min_samples_split=10, n_estimators=100;, score=0.998 total time=  12.8s
# [CV 1/5] END max_depth=100, max_features=0.75, max_leaf_nodes=None, min_samples_split=10, n_estimators=100;, score=0.995 total time=  14.3s
# [CV 3/5] END max_depth=100, max_features=0.75, max_leaf_nodes=None, min_samples_split=10, n_estimators=100;, score=0.998 total time=  13.7s
# [CV 5/5] END max_depth=100, max_features=0.75, max_leaf_nodes=None, min_samples_split=10, n_estimators=100;, score=1.000 total time=  14.0s
# [CV 4/5] END max_depth=100, max_features=0.75, max_leaf_nodes=None, min_samples_split=10, n_estimators=100;, score=0.995 total time=  15.7s
# [CV 2/5] END max_depth=100, max_features=0.75, max_leaf_nodes=None, min_samples_split=10, n_estimators=150;, score=0.998 total time=  17.3s
# [CV 1/5] END max_depth=100, max_features=0.75, max_leaf_nodes=None, min_samples_split=10, n_estimators=150;, score=0.995 total time=  19.3s
# [CV 3/5] END max_depth=100, max_features=0.75, max_leaf_nodes=None, min_samples_split=10, n_estimators=150;, score=0.998 total time=  17.8s
# [CV 5/5] END max_depth=100, max_features=0.75, max_leaf_nodes=None, min_samples_split=10, n_estimators=150;, score=0.999 total time=  15.7s
# [CV 4/5] END max_depth=100, max_features=0.75, max_leaf_nodes=None, min_samples_split=10, n_estimators=150;, score=0.995 total time=  17.3s
# GridSearchCV(estimator=RandomForestClassifier(min_samples_split=5,
#                                               random_state=42),
#              n_jobs=-1,
#              param_grid={'max_depth': [None, 3, 51, 100],
#                          'max_features': ['sqrt', 0.5, 0.75],
#                          'max_leaf_nodes': [20, 60, 100, None],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': array([ 50, 100, 150])},
#              scoring=make_scorer(matthews_corrcoef), verbose=5)

# %%
print(rand_grid.best_params_)
print(rand_grid.best_score_)

y_pred_grid = rand_grid.best_estimator_.predict(X_test)
print(confusion_matrix(y_test, y_pred_grid))
print("----" * 10)
print(f"Recall is:{round(recall_score(y_test, y_pred_grid),3)}")
print(f"MCC is: {round(matthews_corrcoef(y_test, y_pred_grid),3)}")
print(f"F1 is:{round(f1_score(y_test, y_pred_grid),3)}")
print(f"F2 is: {round(fbeta_score(y_test, y_pred_grid, beta=2),3)}")
print("----" * 10)
calculate_cost(X_test_unscaled, y_test, y_pred_grid)
# Out:
# {'max_depth': None, 'max_features': 0.75, 'max_leaf_nodes': None, 'min_samples_split': 5, 'n_estimators': 150}
# 0.9972426078738141
# [[ 8010 15858]
#  [    7    41]]
# ----------------------------------------
# Recall is:0.854
# MCC is: 0.018
# F1 is:0.005
# F2 is: 0.013
# ----------------------------------------
# You detected 41 fraudulent transactions
# You saved the company 90.0 Million UGX
# You missed 7 fraudulent transactions
# The company now has to reimburse frauds with a total of 7.82 Million UGX
# Total money saved is 82.18 Million UGX
# You incorrectly flagged 15858 legit transactions as fraudulent

# %%
"""{'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_samples_split': 5, 'n_estimators': 100}
0.9995806613048874"""


"""[[23380   488]
 [   18    30]]
----------------------------------------
Recall is:0.625
F1 is:0.106
F2 is: 0.211
----------------------------------------
You detected 30 fraudulent transactions
You saved the company 77.98 Million UGX
You missed 18 fraudulent transactions
The company now has to reimburse frauds with a total of 19.84 Million UGX
Total money saved is 58.14 Million UGX
You incorrectly flagged 488 legit transactions as fraudulent"""
# Out:
# [[23380   488]
#  [   18    30]]
# ----------------------------------------
# Recall is:0.625
# F1 is:0.106
# F2 is: 0.211
# ----------------------------------------
# You detected 30 fraudulent transactions
# You saved the company 77.98 Million UGX
# You missed 18 fraudulent transactions
# The company now has to reimburse frauds with a total of 19.84 Million UGX
# Total money saved is 58.14 Million UGX
# You incorrectly flagged 488 legit transactions as fraudulent

# %%
"""{'max_depth': 10,
 'max_features': 0.5,
 'max_leaf_nodes': 50,
 'min_samples_split': 10,
 'n_estimators': 150}"""

Good_model = RandomForestClassifier(max_depth=10, max_features=0.5, max_leaf_nodes=50, min_samples_split=10, n_estimators=150)

# %%
Good_model = RandomForestClassifier(max_depth=10, max_features=0.5, max_leaf_nodes=50, min_samples_split=10, n_estimators=150)
Good_model.fit(X_train, y_train)
y_pred_new = Good_model.predict(X_test)

# %%
Good_model = RandomForestClassifier(max_depth=10, max_features=0.5, max_leaf_nodes=50, min_samples_split=10, n_estimators=150)
Good_model.fit(X_train, y_train)
y_pred_new = Good_model.predict(X_test)


from Error_analysis import calculate_cost #maybe has to be updated to show some numbers

print(confusion_matrix(y_test, y_pred_new))
print("----" * 10)
print(f"Recall is:{round(recall_score(y_test, y_pred_new),3)}")
print(f"F1 is:{round(f1_score(y_test, y_pred_new),3)}")
print(f"MCC is:{round(matthews_corrcoef(y_test, y_pred_new),3)}")
print("----" * 10)
calculate_cost(X_test_unscaled, y_test, y_pred_new)

"""[[23864     4]
 [    9    39]]
----------------------------------------
Recall is:0.812
F1 is:0.857
MCC is:0.858
----------------------------------------
You detected 39 fraudulent transactions
You saved the company 88.02 Million UGX
You missed 9 fraudulent transactions
The company now has to reimburse frauds with a total of 9.8 Million UGX
Total money saved is 78.22 Million UGX
You incorrectly flagged 4 legit transactions as fraudulent"""
# Out:
# [[23864     4]
#  [    9    39]]
# ----------------------------------------
# Recall is:0.812
# F1 is:0.857
# MCC is:0.858
# ----------------------------------------
# You detected 39 fraudulent transactions
# You saved the company 88.02 Million UGX
# You missed 9 fraudulent transactions
# The company now has to reimburse frauds with a total of 9.8 Million UGX
# Total money saved is 78.22 Million UGX
# You incorrectly flagged 4 legit transactions as fraudulent

# %%
from Error_analysis import get_classification_dfs
TN, FP, FN, TP = get_classification_dfs(X_test_unscaled, y_test, y_pred_new)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /Users/valentin/neuefische/Machine-Learning-Project_Xente-Fraud-Detection/team_modelling_SMOTE.ipynb Cell 27 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/valentin/neuefische/Machine-Learning-Project_Xente-Fraud-Detection/team_modelling_SMOTE.ipynb#ch0000033?line=0'>1</a> from Error_analysis import get_classification_dfs
#       <a href='vscode-notebook-cell:/Users/valentin/neuefische/Machine-Learning-Project_Xente-Fraud-Detection/team_modelling_SMOTE.ipynb#ch0000033?line=1'>2</a> TN, FP, FN, TP = get_classification_dfs(X_test_unscaled, y_test, y_pred_new)
#
# ImportError: cannot import name 'get_classification_dfs' from 'Error_analysis' (/Users/valentin/neuefische/Machine-Learning-Project_Xente-Fraud-Detection/Error_analysis.py)

# %%
confusion_matrix(y_test, y_pred_grid)
# Out:
# array([[23867,     1],
#        [   10,    38]])

# %%
calculate_cost(X_test_unscaled, y_test, y_pred_grid)
# Out:
# You saved the company 86.02 Million UGX
# The company still has to reimburse frauds with a total of 11.8 Million UGX
# Total money saved is 74.22 Million UGX

# %%
#result of long gridsearch , stdscaled and MCC optimized

"""{'max_features': 0.75,
 'max_leaf_nodes': 80,
 'min_samples_split': 5,
 'n_estimators': 125}

 Recall is:0.792
MCC is:0.878

You saved the company 86.02 Million UGX
The company still has to reimburse frauds with a total of 11.8 Million UGX
Total money saved is 74.22 Million UGX""";

# %%
#with stdscaler and MCC optimization 

"""param_grid = {'n_estimators': #np.linspace(100, 200, 5).astype(int),
                    'max_depth': [None] + list(np.linspace(3, 100, 10).astype(int)),
                    'max_features': [0.75], ['sqrt']+ list(np.arange(0.5, 1, 0.25)),
                    'max_leaf_nodes': list(np.linspace(80, 100, 5).astype(int)) + [None],
                    'min_samples_split':[2, 5, 10, 50]
                    }

scorer = make_scorer(matthews_corrcoef)

rand_grid = GridSearchCV(rf, param_grid=param_grid, n_jobs=-1, scoring=scorer, verbose=5)

Recall is:0.7916666666666666
ROC-AUC is:0.895812384782973
F1 is:0.8735632183908045
F-beta is:0.9313725490196079
MCC is:0.8780632982539146

{'max_features': 0.75,
 'max_leaf_nodes': 100,
 'min_samples_split': 5,
 'n_estimators': 125}""";

# %%
# with minmax scaling and smote
"""{'max_depth': None,
 'max_features': 'sqrt',
 'max_leaf_nodes': 50,
 'min_samples_split': 5,
 'n_estimators': 150}

 [[23862     6]
 [   22    26]]
----------------------------------------
Recall is:0.542
F1 is:0.65
MCC is:0.663
You saved the company 74.78 Million UGX
The company still has to reimburse frauds with a total of 23.04 Million UGX
Total money saved is 51.74 Million UGX""";
