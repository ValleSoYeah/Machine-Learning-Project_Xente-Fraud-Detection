# %% [markdown]
# # ***Team Modelling***

# %%
# Import modules

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import precision_score, recall_score, roc_auc_score, roc_curve, confusion_matrix, make_scorer, matthews_corrcoef, f1_score, classification_report, fbeta_score
from sklearn.model_selection import train_test_split, RandomizedSearchCV, GridSearchCV
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from Error_analysis import calculate_cost

RSEED= 42

from imblearn.over_sampling import SMOTE

# %%
# Import Dataset

df= pd.read_csv('data/training_preprocessed.csv')

# %%
y= df.FraudResult
df.drop("FraudResult", axis=1, inplace=True)
X= df
X.drop(["TransactionId"], axis=1, inplace=True)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, random_state=RSEED)
X_test_unscaled = X_test.copy()

# %% [markdown]
# ## SMOTE-ing

# %%
smotifier = SMOTE(random_state=RSEED)

# %%
X_smote, y_smote = smotifier.fit_resample(X_train, y_train)
X_smote = pd.DataFrame(data= X_smote, columns=X_train.columns)
y_smote = pd.DataFrame(data= y_smote, columns=["FraudResult"])
smote_df_combined = X_smote.copy()
smote_df_combined["FraudResult"] = y_smote["FraudResult"]

# %%
smote_df_combined.groupby("FraudResult").count()
# Out:
#               Year  Month   Week    Day  is_workday  is_worktime  SignAmount  \
# FraudResult
# 0            71601  71601  71601  71601       71601        71601       71601
# 1            71601  71601  71601  71601       71601        71601       71601
#
#              ModAmount  ProviderId_1  ProviderId_2  ...  PricingStrategy_2  \
# FraudResult                                         ...
# 0                71601         71601         71601  ...              71601
# 1                71601         71601         71601  ...              71601
#
#              PricingStrategy_4  batch_size  total_transactions_by_customer  \
# FraudResult
# 0                        71601       71601                           71601
# 1                        71601       71601                           71601
#
#              transactions_by_customer_this_month  \
# FraudResult
# 0                                          71601
# 1                                          71601
#
#              transactions_by_customer_this_week  \
# FraudResult
# 0                                         71601
# 1                                         71601
#
#              transactions_by_customer_this_day  day_vs_week  day_vs_month  \
# FraudResult
# 0                                        71601        71601         71601
# 1                                        71601        71601         71601
#
#              week_vs_month
# FraudResult
# 0                    71601
# 1                    71601
#
# [2 rows x 62 columns]

# %% [markdown]
# Simple forest, no scaling

# %%
rf = RandomForestClassifier(random_state=RSEED)
rf.fit(X_smote, y_smote)
# Out:
# /var/folders/hs/zvkng9r54wg2zhd69f8h_f280000gn/T/ipykernel_75518/1938663775.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_smote, y_smote)
# RandomForestClassifier(random_state=42)

# %%
y_pred = rf.predict(X_test)

# %%
print(confusion_matrix(y_test, y_pred))
print("----" * 10)
print(f"Recall is:{round(recall_score(y_test, y_pred),3)}")
print(f"F1 is:{round(f1_score(y_test, y_pred),3)}")
print(f"MCC is:{round(matthews_corrcoef(y_test, y_pred),3)}")
calculate_cost(X_test_unscaled, y_test, y_pred)
# Out:
# [[23857    11]
#  [   16    32]]
# ----------------------------------------
# Recall is:0.667
# F1 is:0.703
# MCC is:0.704
# You detected 32 fraudulent transactions
# You saved the company 84.82 Million UGX
# You missed 16 fraudulent transactions
# The company now has to reimburse frauds with a total of 13.0 Million UGX
# Total money saved is 71.82 Million UGX
# You incorrectly flagged 11 legit transactions as fraudulent

# %% [markdown]
# Scaling

# %%
stdsc = StandardScaler()
X_train['ModAmount'] = stdsc.fit_transform(pd.DataFrame(X_train['ModAmount']))
X_test['ModAmount'] = stdsc.transform(pd.DataFrame(X_test['ModAmount']));
X_smote['ModAmount'] = stdsc.fit_transform(pd.DataFrame(X_smote['ModAmount']))
X_smote['ModAmount'] = stdsc.transform(pd.DataFrame(X_smote['ModAmount']));

# %%
rf = RandomForestClassifier()
rf.fit(X_smote, y_smote)
y_pred = rf.predict(X_test)
print(confusion_matrix(y_test, y_pred))
print("----" * 10)
print(f"Recall is:{round(recall_score(y_test, y_pred),3)}")
print(f"F1 is:{round(f1_score(y_test, y_pred),3)}")
print(f"MCC is:{round(matthews_corrcoef(y_test, y_pred),3)}")
calculate_cost(X_test_unscaled, y_test, y_pred)
# Out:
# /var/folders/hs/zvkng9r54wg2zhd69f8h_f280000gn/T/ipykernel_75518/2593867561.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_smote, y_smote)
# [[23484   384]
#  [   20    28]]
# ----------------------------------------
# Recall is:0.583
# F1 is:0.122
# MCC is:0.195
# You detected 28 fraudulent transactions
# You saved the company 76.04 Million UGX
# You missed 20 fraudulent transactions
# The company now has to reimburse frauds with a total of 21.78 Million UGX
# Total money saved is 54.26 Million UGX
# You incorrectly flagged 384 legit transactions as fraudulent

# %%
"""
param_grid = {'n_estimators': [150,200],
                'max_depth': [10, None], #+ list(np.linspace(3, 100, 5).astype(int)),
                'max_features': ['sqrt'] + list(np.arange(0.5, 0.75, 0.25)),
                'max_leaf_nodes': [20, 50, 75],
                'min_samples_split': [2, 5, 10]
                    }

scorer = make_scorer(matthews_corrcoef)

rand_grid = GridSearchCV(rf, param_grid=param_grid, n_jobs=-1, scoring="roc_auc", verbose=5)"""

# %%
#rand_grid.fit(X_smote, y_smote)
# Out:
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
# [CV 2/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=20, min_samples_split=2, n_estimators=150;, score=1.000 total time=   5.7s
# [CV 3/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=20, min_samples_split=2, n_estimators=150;, score=1.000 total time=   6.1s
# [CV 5/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=20, min_samples_split=2, n_estimators=150;, score=0.975 total time=   5.9s
# [CV 1/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=20, min_samples_split=2, n_estimators=150;, score=1.000 total time=   6.4s
# [CV 4/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=20, min_samples_split=2, n_estimators=150;, score=0.983 total time=   6.2s
# [CV 2/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=20, min_samples_split=2, n_estimators=200;, score=1.000 total time=   8.3s
# [CV 1/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=20, min_samples_split=2, n_estimators=200;, score=1.000 total time=   8.4s
# [CV 3/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=20, min_samples_split=2, n_estimators=200;, score=1.000 total time=   8.3s
# [CV 2/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=20, min_samples_split=5, n_estimators=150;, score=1.000 total time=   5.4s
# [CV 3/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=20, min_samples_split=5, n_estimators=150;, score=1.000 total time=   5.5s
# [CV 1/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=20, min_samples_split=5, n_estimators=150;, score=1.000 total time=   6.0s
# [CV 5/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=20, min_samples_split=2, n_estimators=200;, score=0.975 total time=   7.3s
# [CV 4/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=20, min_samples_split=2, n_estimators=200;, score=0.984 total time=   8.0s
# [CV 4/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=20, min_samples_split=5, n_estimators=150;, score=0.981 total time=   5.7s
# [CV 5/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=20, min_samples_split=5, n_estimators=150;, score=0.971 total time=   5.8s
# [CV 1/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=20, min_samples_split=5, n_estimators=200;, score=1.000 total time=   7.8s
# [CV 2/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=20, min_samples_split=5, n_estimators=200;, score=1.000 total time=   7.1s
# [CV 1/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=20, min_samples_split=10, n_estimators=150;, score=1.000 total time=   5.5s
# [CV 2/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=20, min_samples_split=10, n_estimators=150;, score=1.000 total time=   5.3s
# [CV 4/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=20, min_samples_split=5, n_estimators=200;, score=0.987 total time=   7.1s
# [CV 3/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=20, min_samples_split=5, n_estimators=200;, score=1.000 total time=   7.4s
# [CV 3/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=20, min_samples_split=10, n_estimators=150;, score=1.000 total time=   5.5s
# [CV 5/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=20, min_samples_split=5, n_estimators=200;, score=0.974 total time=   7.0s
# [CV 4/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=20, min_samples_split=10, n_estimators=150;, score=0.993 total time=   5.8s
# [CV 5/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=20, min_samples_split=10, n_estimators=150;, score=0.995 total time=   5.6s
# [CV 3/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=20, min_samples_split=10, n_estimators=200;, score=1.000 total time=   6.9s
# [CV 2/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=20, min_samples_split=10, n_estimators=200;, score=1.000 total time=   7.2s
# [CV 4/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=20, min_samples_split=10, n_estimators=200;, score=0.993 total time=   6.9s
# [CV 1/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=20, min_samples_split=10, n_estimators=200;, score=1.000 total time=   7.5s
# [CV 5/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=20, min_samples_split=10, n_estimators=200;, score=0.994 total time=   6.8s
# [CV 1/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=50, min_samples_split=2, n_estimators=150;, score=1.000 total time=   6.7s
# [CV 2/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=50, min_samples_split=2, n_estimators=150;, score=1.000 total time=   6.1s
# [CV 3/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=50, min_samples_split=2, n_estimators=150;, score=1.000 total time=   5.6s
# [CV 4/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=50, min_samples_split=2, n_estimators=150;, score=0.982 total time=   5.5s
# [CV 5/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=50, min_samples_split=2, n_estimators=150;, score=0.995 total time=   5.4s
# [CV 3/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=50, min_samples_split=2, n_estimators=200;, score=1.000 total time=   7.3s
# [CV 2/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=50, min_samples_split=2, n_estimators=200;, score=1.000 total time=   7.4s
# [CV 4/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=50, min_samples_split=2, n_estimators=200;, score=0.985 total time=   7.1s
# [CV 1/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=50, min_samples_split=2, n_estimators=200;, score=1.000 total time=   7.9s
# [CV 5/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=50, min_samples_split=2, n_estimators=200;, score=0.995 total time=   7.7s
# [CV 1/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=50, min_samples_split=5, n_estimators=150;, score=1.000 total time=   6.8s
# [CV 2/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=50, min_samples_split=5, n_estimators=150;, score=1.000 total time=   6.8s
# [CV 3/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=50, min_samples_split=5, n_estimators=150;, score=1.000 total time=   6.8s
# [CV 5/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=50, min_samples_split=5, n_estimators=150;, score=0.995 total time=   6.0s
# [CV 4/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=50, min_samples_split=5, n_estimators=150;, score=0.999 total time=   6.5s
# [CV 2/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=50, min_samples_split=5, n_estimators=200;, score=1.000 total time=   8.1s
# [CV 1/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=50, min_samples_split=5, n_estimators=200;, score=1.000 total time=   8.5s
# [CV 3/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=50, min_samples_split=5, n_estimators=200;, score=1.000 total time=   8.4s
# [CV 4/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=50, min_samples_split=5, n_estimators=200;, score=0.999 total time=   8.6s
# [CV 1/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=50, min_samples_split=10, n_estimators=150;, score=1.000 total time=   7.1s
# [CV 5/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=50, min_samples_split=5, n_estimators=200;, score=0.994 total time=   8.3s
# [CV 2/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=50, min_samples_split=10, n_estimators=150;, score=1.000 total time=   7.1s
# [CV 3/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=50, min_samples_split=10, n_estimators=150;, score=1.000 total time=   7.2s
# [CV 5/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=50, min_samples_split=10, n_estimators=150;, score=0.999 total time=   6.6s
# [CV 4/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=50, min_samples_split=10, n_estimators=150;, score=0.993 total time=   6.9s
# [CV 1/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=50, min_samples_split=10, n_estimators=200;, score=1.000 total time=  10.2s
# [CV 2/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=50, min_samples_split=10, n_estimators=200;, score=1.000 total time=   9.0s
# [CV 3/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=50, min_samples_split=10, n_estimators=200;, score=1.000 total time=   8.8s
# [CV 1/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=75, min_samples_split=2, n_estimators=150;, score=1.000 total time=   8.1s
# [CV 4/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=50, min_samples_split=10, n_estimators=200;, score=0.992 total time=   9.6s
# [CV 5/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=50, min_samples_split=10, n_estimators=200;, score=0.999 total time=   9.6s
# [CV 2/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=75, min_samples_split=2, n_estimators=150;, score=1.000 total time=   8.4s
# [CV 3/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=75, min_samples_split=2, n_estimators=150;, score=1.000 total time=   8.6s
# [CV 4/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=75, min_samples_split=2, n_estimators=150;, score=0.997 total time=   8.0s
# [CV 5/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=75, min_samples_split=2, n_estimators=150;, score=0.999 total time=   8.3s
# [CV 1/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=75, min_samples_split=2, n_estimators=200;, score=1.000 total time=  12.1s
# [CV 1/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=75, min_samples_split=5, n_estimators=150;, score=1.000 total time=   8.8s
# [CV 2/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=75, min_samples_split=2, n_estimators=200;, score=1.000 total time=  11.4s
# [CV 4/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=75, min_samples_split=2, n_estimators=200;, score=0.997 total time=  10.6s
# [CV 3/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=75, min_samples_split=2, n_estimators=200;, score=1.000 total time=  11.5s
# [CV 5/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=75, min_samples_split=2, n_estimators=200;, score=0.999 total time=  10.8s
# [CV 2/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=75, min_samples_split=5, n_estimators=150;, score=1.000 total time=   7.9s
# [CV 3/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=75, min_samples_split=5, n_estimators=150;, score=1.000 total time=   7.7s
# [CV 4/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=75, min_samples_split=5, n_estimators=150;, score=0.998 total time=   6.1s
# [CV 5/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=75, min_samples_split=5, n_estimators=150;, score=0.996 total time=   6.3s
# [CV 2/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=75, min_samples_split=5, n_estimators=200;, score=1.000 total time=   9.2s
# [CV 1/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=75, min_samples_split=5, n_estimators=200;, score=1.000 total time=   9.9s
# [CV 3/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=75, min_samples_split=5, n_estimators=200;, score=1.000 total time=   9.7s
# [CV 4/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=75, min_samples_split=5, n_estimators=200;, score=0.999 total time=   9.5s
# [CV 1/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=75, min_samples_split=10, n_estimators=150;, score=1.000 total time=   8.3s
# [CV 5/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=75, min_samples_split=5, n_estimators=200;, score=0.995 total time=   9.6s
# [CV 3/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=75, min_samples_split=10, n_estimators=150;, score=1.000 total time=   8.0s
# [CV 2/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=75, min_samples_split=10, n_estimators=150;, score=1.000 total time=   8.3s
# [CV 4/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=75, min_samples_split=10, n_estimators=150;, score=0.994 total time=   7.9s
# [CV 5/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=75, min_samples_split=10, n_estimators=150;, score=0.999 total time=   7.9s
# [CV 2/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=75, min_samples_split=10, n_estimators=200;, score=1.000 total time=  10.4s
# [CV 1/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=75, min_samples_split=10, n_estimators=200;, score=1.000 total time=  10.9s
# [CV 3/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=75, min_samples_split=10, n_estimators=200;, score=1.000 total time=  10.2s
# [CV 4/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=75, min_samples_split=10, n_estimators=200;, score=0.993 total time=   9.9s
# [CV 5/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=75, min_samples_split=10, n_estimators=200;, score=0.999 total time=  10.2s
# [CV 1/5] END max_depth=10, max_features=0.5, max_leaf_nodes=20, min_samples_split=2, n_estimators=150;, score=1.000 total time=  17.0s
# [CV 2/5] END max_depth=10, max_features=0.5, max_leaf_nodes=20, min_samples_split=2, n_estimators=150;, score=1.000 total time=  16.2s
# [CV 3/5] END max_depth=10, max_features=0.5, max_leaf_nodes=20, min_samples_split=2, n_estimators=150;, score=1.000 total time=  16.1s
# [CV 4/5] END max_depth=10, max_features=0.5, max_leaf_nodes=20, min_samples_split=2, n_estimators=150;, score=1.000 total time=  14.7s
# [CV 5/5] END max_depth=10, max_features=0.5, max_leaf_nodes=20, min_samples_split=2, n_estimators=150;, score=1.000 total time=  14.9s
# [CV 1/5] END max_depth=10, max_features=0.5, max_leaf_nodes=20, min_samples_split=2, n_estimators=200;, score=1.000 total time=  20.0s
# [CV 2/5] END max_depth=10, max_features=0.5, max_leaf_nodes=20, min_samples_split=2, n_estimators=200;, score=1.000 total time=  21.0s
# [CV 3/5] END max_depth=10, max_features=0.5, max_leaf_nodes=20, min_samples_split=2, n_estimators=200;, score=1.000 total time=  20.3s
# [CV 1/5] END max_depth=10, max_features=0.5, max_leaf_nodes=20, min_samples_split=5, n_estimators=150;, score=1.000 total time=  14.8s
# [CV 4/5] END max_depth=10, max_features=0.5, max_leaf_nodes=20, min_samples_split=2, n_estimators=200;, score=1.000 total time=  18.3s
# [CV 2/5] END max_depth=10, max_features=0.5, max_leaf_nodes=20, min_samples_split=5, n_estimators=150;, score=1.000 total time=  14.8s
# [CV 3/5] END max_depth=10, max_features=0.5, max_leaf_nodes=20, min_samples_split=5, n_estimators=150;, score=1.000 total time=  14.8s
# [CV 5/5] END max_depth=10, max_features=0.5, max_leaf_nodes=20, min_samples_split=2, n_estimators=200;, score=1.000 total time=  18.7s
# [CV 4/5] END max_depth=10, max_features=0.5, max_leaf_nodes=20, min_samples_split=5, n_estimators=150;, score=1.000 total time=  14.8s
# [CV 5/5] END max_depth=10, max_features=0.5, max_leaf_nodes=20, min_samples_split=5, n_estimators=150;, score

# [CV 4/5] END max_depth=None, max_features=0.5, max_leaf_nodes=20, min_samples_split=10, n_estimators=150;, score=1.000 total time=  12.8s
# [CV 5/5] END max_depth=None, max_features=0.5, max_leaf_nodes=20, min_samples_split=10, n_estimators=150;, score=1.000 total time=  13.4s
# [CV 4/5] END max_depth=None, max_features=0.5, max_leaf_nodes=20, min_samples_split=10, n_estimators=200;, score=1.000 total time=  16.6s
# [CV 1/5] END max_depth=None, max_features=0.5, max_leaf_nodes=20, min_samples_split=10, n_estimators=200;, score=1.000 total time=  19.1s
# [CV 2/5] END max_depth=None, max_features=0.5, max_leaf_nodes=20, min_samples_split=10, n_estimators=200;, score=1.000 total time=  19.3s
# [CV 3/5] END max_depth=None, max_features=0.5, max_leaf_nodes=20, min_samples_split=10, n_estimators=200;, score=1.000 total time=  19.0s
# [CV 1/5] END max_depth=None, max_features=0.5, max_leaf_nodes=50, min_samples_split=2, n_estimators=150;, score=1.000 total time=  15.6s
# [CV 5/5] END max_depth=None, max_features=0.5, max_leaf_nodes=20, min_samples_split=10, n_estimators=200;, score=1.000 total time=  18.1s
# [CV 2/5] END max_depth=None, max_features=0.5, max_leaf_nodes=50, min_samples_split=2, n_estimators=150;, score=1.000 total time=  15.0s
# [CV 3/5] END max_depth=None, max_features=0.5, max_leaf_nodes=50, min_samples_split=2, n_estimators=150;, score=1.000 total time=  15.2s
# [CV 4/5] END max_depth=None, max_features=0.5, max_leaf_nodes=50, min_samples_split=2, n_estimators=150;, score=1.000 total time=  13.2s
# [CV 5/5] END max_depth=None, max_features=0.5, max_leaf_nodes=50, min_samples_split=2, n_estimators=150;, score=1.000 total time=  14.1s
# [CV 4/5] END max_depth=None, max_features=0.5, max_leaf_nodes=50, min_samples_split=2, n_estimators=200;, score=1.000 total time=  17.6s
# [CV 2/5] END max_depth=None, max_features=0.5, max_leaf_nodes=50, min_samples_split=2, n_estimators=200;, score=1.000 total time=  19.7s
# [CV 1/5] END max_depth=None, max_features=0.5, max_leaf_nodes=50, min_samples_split=2, n_estimators=200;, score=1.000 total time=  20.8s
# [CV 3/5] END max_depth=None, max_features=0.5, max_leaf_nodes=50, min_samples_split=2, n_estimators=200;, score=1.000 total time=  20.4s
# [CV 1/5] END max_depth=None, max_features=0.5, max_leaf_nodes=50, min_samples_split=5, n_estimators=150;, score=1.000 total time=  15.1s
# [CV 5/5] END max_depth=None, max_features=0.5, max_leaf_nodes=50, min_samples_split=2, n_estimators=200;, score=1.000 total time=  19.5s
# [CV 2/5] END max_depth=None, max_features=0.5, max_leaf_nodes=50, min_samples_split=5, n_estimators=150;, score=1.000 total time=  15.2s
# [CV 3/5] END max_depth=None, max_features=0.5, max_leaf_nodes=50, min_samples_split=5, n_estimators=150;, score=1.000 total time=  15.1s
# [CV 4/5] END max_depth=None, max_features=0.5, max_leaf_nodes=50, min_samples_split=5, n_estimators=150;, score=1.000 total time=  13.5s
# [CV 5/5] END max_depth=None, max_features=0.5, max_leaf_nodes=50, min_samples_split=5, n_estimators=150;, score=1.000 total time=  14.5s
# [CV 1/5] END max_depth=None, max_features=0.5, max_leaf_nodes=50, min_samples_split=5, n_estimators=200;, score=1.000 total time=  20.6s
# [CV 4/5] END max_depth=None, max_features=0.5, max_leaf_nodes=50, min_samples_split=5, n_estimators=200;, score=1.000 total time=  17.9s
# [CV 2/5] END max_depth=None, max_features=0.5, max_leaf_nodes=50, min_samples_split=5, n_estimators=200;, score=1.000 total time=  20.4s
# [CV 1/5] END max_depth=None, max_features=0.5, max_leaf_nodes=50, min_samples_split=10, n_estimators=150;, score=1.000 total time=  15.2s
# [CV 3/5] END max_depth=None, max_features=0.5, max_leaf_nodes=50, min_samples_split=5, n_estimators=200;, score=1.000 total time=  20.7s
# [CV 5/5] END max_depth=None, max_features=0.5, max_leaf_nodes=50, min_samples_split=5, n_estimators=200;, score=1.000 total time=  19.0s
# [CV 2/5] END max_depth=None, max_features=0.5, max_leaf_nodes=50, min_samples_split=10, n_estimators=150;, score=1.000 total time=  15.4s
# [CV 3/5] END max_depth=None, max_features=0.5, max_leaf_nodes=50, min_samples_split=10, n_estimators=150;, score=1.000 total time=  15.4s
# [CV 4/5] END max_depth=None, max_features=0.5, max_leaf_nodes=50, min_samples_split=10, n_estimators=150;, score=1.000 total time=  13.7s
# [CV 5/5] END max_depth=None, max_features=0.5, max_leaf_nodes=50, min_samples_split=10, n_estimators=150;, score=1.000 total time=  14.7s
# [CV 1/5] END max_depth=None, max_features=0.5, max_leaf_nodes=50, min_samples_split=10, n_estimators=200;, score=1.000 total time=  20.9s
# [CV 4/5] END max_depth=None, max_features=0.5, max_leaf_nodes=50, min_samples_split=10, n_estimators=200;, score=1.000 total time=  17.5s
# [CV 2/5] END max_depth=None, max_features=0.5, max_leaf_nodes=50, min_samples_split=10, n_estimators=200;, score=1.000 total time=  20.6s
# [CV 3/5] END max_depth=None, max_features=0.5, max_leaf_nodes=50, min_samples_split=10, n_estimators=200;, score=1.000 total time=  20.5s
# [CV 1/5] END max_depth=None, max_features=0.5, max_leaf_nodes=75, min_samples_split=2, n_estimators=150;, score=1.000 total time=  16.3s
# [CV 5/5] END max_depth=None, max_features=0.5, max_leaf_nodes=50, min_samples_split=10, n_estimators=200;, score=1.000 total time=  19.5s
# [CV 2/5] END max_depth=None, max_features=0.5, max_leaf_nodes=75, min_samples_split=2, n_estimators=150;, score=1.000 total time=  15.3s
# [CV 3/5] END max_depth=None, max_features=0.5, max_leaf_nodes=75, min_samples_split=2, n_estimators=150;, score=1.000 total time=  15.7s
# [CV 4/5] END max_depth=None, max_features=0.5, max_leaf_nodes=75, min_samples_split=2, n_estimators=150;, score=1.000 total time=  13.6s
# [CV 5/5] END max_depth=None, max_features=0.5, max_leaf_nodes=75, min_samples_split=2, n_estimators=150;, score=0.983 total time=  14.9s
# [CV 1/5] END max_depth=None, max_features=0.5, max_leaf_nodes=75, min_samples_split=2, n_estimators=200;, score=1.000 total time=  21.0s
# [CV 2/5] END max_depth=None, max_features=0.5, max_leaf_nodes=75, min_samples_split=2, n_estimators=200;, score=1.000 total time=  20.7s
# [CV 4/5] END max_depth=None, max_features=0.5, max_leaf_nodes=75, min_samples_split=2, n_estimators=200;, score=1.000 total time=  18.4s
# [CV 3/5] END max_depth=None, max_features=0.5, max_leaf_nodes=75, min_samples_split=2, n_estimators=200;, score=1.000 total time=  21.2s
# [CV 1/5] END max_depth=None, max_features=0.5, max_leaf_nodes=75, min_samples_split=5, n_estimators=150;, score=1.000 total time=  15.7s
# [CV 5/5] END max_depth=None, max_features=0.5, max_leaf_nodes=75, min_samples_split=2, n_estimators=200;, score=0.983 total time=  20.1s
# [CV 2/5] END max_depth=None, max_features=0.5, max_leaf_nodes=75, min_samples_split=5, n_estimators=150;, score=1.000 total time=  16.0s
# [CV 3/5] END max_depth=None, max_features=0.5, max_leaf_nodes=75, min_samples_split=5, n_estimators=150;, score=1.000 total time=  15.8s
# [CV 4/5] END max_depth=None, max_features=0.5, max_leaf_nodes=75, min_samples_split=5, n_estimators=150;, score=1.000 total time=  13.7s
# [CV 5/5] END max_depth=None, max_features=0.5, max_leaf_nodes=75, min_samples_split=5, n_estimators=150;, score=1.000 total time=  15.1s
# [CV 1/5] END max_depth=None, max_features=0.5, max_leaf_nodes=75, min_samples_split=5, n_estimators=200;, score=1.000 total time=  21.2s
# [CV 2/5] END max_depth=None, max_features=0.5, max_leaf_nodes=75, min_samples_split=5, n_estimators=200;, score=1.000 total time=  20.5s
# [CV 4/5] END max_depth=None, max_features=0.5, max_leaf_nodes=75, min_samples_split=5, n_estimators=200;, score=1.000 total time=  18.3s
# [CV 3/5] END max_depth=None, max_features=0.5, max_leaf_nodes=75, min_samples_split=5, n_estimators=200;, score=1.000 total time=  21.5s
# [CV 1/5] END max_depth=None, max_features=0.5, max_leaf_nodes=75, min_samples_split=10, n_estimators=150;, score=1.000 total time=  15.9s
# [CV 5/5] END max_depth=None, max_features=0.5, max_leaf_nodes=75, min_samples_split=5, n_estimators=200;, score=1.000 total time=  20.0s
# [CV 2/5] END max_depth=None, max_features=0.5, max_leaf_nodes=75, min_samples_split=10, n_estimators=150;, score=1.000 total time=  15.8s
# [CV 3/5] END max_depth=None, max_features=0.5, max_leaf_nodes=75, min_samples_split=10, n_estimators=150;, score=1.000 total time=  15.6s
# [CV 4/5] END max_depth=None, max_features=0.5, max_leaf_nodes=75, min_samples_split=10, n_estimators=150;, score=1.000 total time=  13.4s
# [CV 5/5] END max_depth=None, max_features=0.5, max_leaf_nodes=75, min_samples_split=10, n_estimators=150;, score=1.000 total time=  14.1s
# [CV 1/5] END max_depth=None, max_features=0.5, max_leaf_nodes=75, min_samples_split=10, n_estimators=200;, score=1.000 total time=  18.4s
# [CV 2/5] END max_depth=None, max_features=0.5, max_leaf_nodes=75, min_samples_split=10, n_estimators=200;, score=1.000 total time=  18.3s
# [CV 4/5] END max_depth=None, max_features=0.5, max_leaf_nodes=75, min_samples_split=10, n_estimators=200;, score=1.000 total time=  15.7s
# [CV 3/5] END max_depth=None, max_features=0.5, max_leaf_nodes=75, min_samples_split=10, n_estimators=200;, score=1.000 total time=  18.1s
# [CV 5/5] END max_depth=None, max_features=0.5, max_leaf_nodes=75, min_samples_split=10, n_estimators=200;, score=1.000 total time=  14.8s
# GridSearchCV(estimator=RandomForestClassifier(random_state=42), n_jobs=-1,
#              param_grid={'max_depth': [10, None], 'max_features': ['sqrt', 0.5],
#                          'max_leaf_nodes': [20, 50, 75],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [150, 200]},
#              scoring='roc_auc', verbose=5)

# %%
rand_grid.best_params_
"""{'max_depth': 10,
 'max_features': 0.5,
 'max_leaf_nodes': 50,
 'min_samples_split': 10,
 'n_estimators': 150}"""
# Out:
# {'max_depth': 10,
#  'max_features': 0.5,
#  'max_leaf_nodes': 50,
#  'min_samples_split': 10,
#  'n_estimators': 150}

# %%
rf_best = RandomForestClassifier(max_depth= 10, max_features = 0.5, max_leaf_nodes = 50, min_samples_split = 10, n_estimators = 150)
rf_best.fit(X_smote, y_smote)
y_pred_best = rf_best.predict(X_test)
print(confusion_matrix(y_test, y_pred_best))
print("----" * 10)
print(f"Recall is:{round(recall_score(y_test, y_pred_best),3)}")
print(f"F1 is:{round(f1_score(y_test, y_pred_best),3)}")
print(f"MCC is:{round(matthews_corrcoef(y_test, y_pred_best),3)}")
calculate_cost(X_test_unscaled, y_test, y_pred_best)
# Out:
# /var/folders/hs/zvkng9r54wg2zhd69f8h_f280000gn/T/ipykernel_75518/1013242424.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf_best.fit(X_smote, y_smote)
# [[22515  1353]
#  [   12    36]]
# ----------------------------------------
# Recall is:0.75
# F1 is:0.05
# MCC is:0.133
# You detected 36 fraudulent transactions
# You saved the company 84.27 Million UGX
# You missed 12 fraudulent transactions
# The company now has to reimburse frauds with a total of 13.54 Million UGX
# Total money saved is 70.72 Million UGX
# You incorrectly flagged 1353 legit transactions as fraudulent
